# %% [markdown]
# #### Create the environment

# %%
# In your_notebook.ipynb
from env_creator import energy_management_env_creator
from energy_management_env import EnergyManagementEnv
import gym

# %run register_env.py

# Register the environment
energy_management_env_creator(SOC_min=0.2, SOC_max=0.8, E=1000, lambda_val=10, data_path='Data_input_v2.csv', initial_SOC=0.5)

# Create the environment
env = gym.make('EnergyManagement-v0')

# %% [markdown]
# ##### Test the environment

# %%
import gym
# Run a simulation loop
observation = env.reset()
for t in range(10):
    # Print information before and after taking action
    print(f"Step {t + 1}:")
    
    # Before Action
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")
    
    # Take a random action
    action = env.action_space.sample()
    observation, reward, done, _ = env.step(action)

    # After Action
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()
# Out:
# Step 1:
#   Before Action: Demand=174.72, Price=23.96, SOC=0.50  |  After Action: Action=0.00, Reward=-1.79e+01, New SOC=0.40
#
# Step 2:
#   Before Action: Demand=163.20, Price=22.80, SOC=0.40  |  After Action: Action=2.00, Reward=-6.00e+01, New SOC=0.50
#
# Step 3:
#   Before Action: Demand=150.72, Price=20.79, SOC=0.50  |  After Action: Action=0.00, Reward=-1.05e+01, New SOC=0.40
#
# Step 4:
#   Before Action: Demand=148.80, Price=19.87, SOC=0.40  |  After Action: Action=1.00, Reward=-2.96e+01, New SOC=0.40
#
# Step 5:
#   Before Action: Demand=149.76, Price=19.33, SOC=0.40  |  After Action: Action=0.00, Reward=-9.62e+00, New SOC=0.30
#
# Step 6:
#   Before Action: Demand=148.80, Price=18.90, SOC=0.30  |  After Action: Action=1.00, Reward=-2.81e+01, New SOC=0.30
#
# Step 7:
#   Before Action: Demand=142.08, Price=17.82, SOC=0.30  |  After Action: Action=0.00, Reward=-7.50e+00, New SOC=0.20
#
# Step 8:
#   Before Action: Demand=144.00, Price=19.76, SOC=0.20  |  After Action: Action=2.00, Reward=-4.82e+01, New SOC=0.30
#
# Step 9:
#   Before Action: Demand=153.60, Price=23.84, SOC=0.30  |  After Action: Action=1.00, Reward=-3.66e+01, New SOC=0.30
#
# Step 10:
#   Before Action: Demand=170.88, Price=39.94, SOC=0.30  |  After Action: Action=0.00, Reward=-2.83e+01, New SOC=0.20
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:141: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %% [markdown]
# ##### PPO

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

# Register the custom environment (assuming you have already registered it)
env_id = 'EnergyManagement-v0'

# Define a function to create the environment
def make_env():
    return gym.make(env_id)

# Create the vectorized environment with 8 parallel environments using DummyVecEnv
num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])

# Wrap the vectorized environment with VecNormalize
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("ppo_energy_management")

del model  # Remove to demonstrate saving and loading

model = PPO.load("ppo_energy_management")
print("Training Done")
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:141: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# ------------------------------
# | time/              |       |
# |    fps             | 3786  |
# |    iterations      | 1     |
# |    time_elapsed    | 4     |
# |    total_timesteps | 16384 |
# ------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1062      |
# |    iterations           | 2         |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.18e+15  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -9.08e-08 |
# |    value_loss           | 9.67e+15  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 818       |
# |    iterations           | 3         |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.06e+16  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -6.55e-09 |
# |    value_loss           | 1.18e+17  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 738       |
# |    iterations           | 4         |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.66e+17  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -9.02e-09 |
# |    value_loss           | 3.29e+17  |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 719      |
# |    iterations           | 5        |
# |    time_elapsed         | 113      |
# |    total_timesteps      | 81920    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.1     |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.96e+17 |
# |    n_updates            | 40       |
# |    policy_gradient_loss | -1e-10   |
# |    value_loss           | 8.65e+17 |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 705       |
# |    iterations           | 6         |
# |    time_elapsed         | 139       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.52e+17  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -6.95e-10 |
# |    value_loss           | 1.16e+18  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 706       |
# |    iterations           | 7         |
# |    time_elapsed         | 162       |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.89e+17  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -1.13e-09 |
# |    value_loss           | 1.34e+18  |
# ---------------------------------------
# Training Done
# Step 1:
#   Before Action: Demand=174.72, Price=23.96, SOC=0.50  |  After Action: Action=0.00, Reward=-1.79e+01, New SOC=0.40
#
# Step 2:
#   Before Action: Demand=163.20, Price=22.80, SOC=0.40  |  After Action: Action=0.00, Reward=-1.44e+01, New SOC=0.30
#
# Step 3:
#   Before Action: Demand=150.72, Price=20.79, SOC=0.30  |  After Action: Action=0.00, Reward=-1.05e+01, New SOC=0.20
#
# Step 4:
#   Before Action: Demand=148.80, Price=19.87, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 5:
#   Before Action: Demand=149.76, Price=19.33, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 6:
#   Before Action: Demand=148.80, Price=18.90, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 7:
#   Before Action: Demand=142.08, Price=17.82, SOC=0.00  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 8:
#   Before Action: Demand=144.00, Price=19.76, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 9:
#   Before Action: Demand=153.60, Price=23.84, SOC=-0.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 10:
#   Before Action: Demand=170.88, Price=39.94, SOC=-0.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 11:
#   Before Action: Demand=176.64, Price=42.09, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 12:
#   Before Action: Demand=190.08, Price=45.77, SOC=-0.30  |  After Action: Action=0.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 13:
#   Before Action: Demand=203.52, Price=35.78, SOC=-0.40  |  After Action: Action=2.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 14:
#   Before Action: Demand=204.48, Price=45.41, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 15:
#   Before Action: Demand=198.72, Price=48.06, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 16:
#   Before Action: Demand=219.84, Price=43.56, SOC=-0.30  |  After Action: Action=1.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 17:
#   Before Action: Demand=214.08, Price=53.45, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 18:
#   Before Action: Demand=192.96, Price=52.10, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 19:
#   Before Action: Demand=189.12, Price=49.46, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 20:
#   Before Action: Demand=184.32, Price=44.55, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 21:
#   Before Action: Demand=184.32, Price=36.28, SOC=-0.10  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=-0.00
#
# Step 22:
#   Before Action: Demand=174.72, Price=35.53, SOC=-0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 23:
#   Before Action: Demand=175.68, Price=28.37, SOC=0.10  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 24:
#   Before Action: Demand=166.08, Price=27.72, SOC=0.10  |  After Action: Action=2.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 25:
#   Before Action: Demand=160.32, Price=28.12, SOC=0.20  |  After Action: Action=2.00, Reward=-7.32e+01, New SOC=0.30
#
# Step 26:
#   Before Action: Demand=161.28, Price=21.92, SOC=0.30  |  After Action: Action=2.00, Reward=-5.73e+01, New SOC=0.40
#
# Step 27:
#   Before Action: Demand=155.52, Price=21.23, SOC=0.40  |  After Action: Action=0.00, Reward=-1.18e+01, New SOC=0.30
#
# Step 28:
#   Before Action: Demand=153.60, Price=20.49, SOC=0.30  |  After Action: Action=0.00, Reward=-1.10e+01, New SOC=0.20
#
# Step 29:
#   Before Action: Demand=155.52, Price=20.39, SOC=0.20  |  After Action: Action=2.00, Reward=-5.21e+01, New SOC=0.30
#
# Step 30:
#   Before Action: Demand=161.28, Price=20.96, SOC=0.30  |  After Action: Action=2.00, Reward=-5.48e+01, New SOC=0.40
#
# Step 31:
#   Before Action: Demand=155.52, Price=23.53, SOC=0.40  |  After Action: Action=0.00, Reward=-1.31e+01, New SOC=0.30
#
# Step 32:
#   Before Action: Demand=199.68, Price=26.07, SOC=0.30  |  After Action: Action=2.00, Reward=-7.81e+01, New SOC=0.40
#
# Step 33:
#   Before Action: Demand=350.40, Price=34.18, SOC=0.40  |  After Action: Action=0.00, Reward=-8.56e+01, New SOC=0.30
#
# Step 34:
#   Before Action: Demand=558.72, Price=78.11, SOC=0.30  |  After Action: Action=0.00, Reward=-3.58e+02, New SOC=0.20
#
# Step 35:
#   Before Action: Demand=722.88, Price=41.33, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 36:
#   Before Action: Demand=724.80, Price=82.04, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 37:
#   Before Action: Demand=728.64, Price=83.48, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 38:
#   Before Action: Demand=753.60, Price=57.58, SOC=0.00  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 39:
#   Before Action: Demand=818.88, Price=50.23, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 40:
#   Before Action: Demand=878.40, Price=41.85, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 41:
#   Before Action: Demand=877.44, Price=44.76, SOC=-0.10  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 42:
#   Before Action: Demand=799.68, Price=41.69, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 43:
#   Before Action: Demand=689.28, Price=78.20, SOC=0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 44:
#   Before Action: Demand=504.96, Price=56.38, SOC=0.10  |  After Action: Action=2.00, Reward=-3.41e+02, New SOC=0.20
#
# Step 45:
#   Before Action: Demand=359.04, Price=41.93, SOC=0.20  |  After Action: Action=2.00, Reward=-1.92e+02, New SOC=0.30
#
# Step 46:
#   Before Action: Demand=291.84, Price=32.07, SOC=0.30  |  After Action: Action=2.00, Reward=-1.26e+02, New SOC=0.40
#
# Step 47:
#   Before Action: Demand=248.64, Price=30.79, SOC=0.40  |  After Action: Action=1.00, Reward=-7.66e+01, New SOC=0.40
#
# Step 48:
#   Before Action: Demand=201.60, Price=32.51, SOC=0.40  |  After Action: Action=2.00, Reward=-9.81e+01, New SOC=0.50
#
# Step 49:
#   Before Action: Demand=182.40, Price=29.05, SOC=0.50  |  After Action: Action=0.00, Reward=-2.39e+01, New SOC=0.40
#
# Step 50:
#   Before Action: Demand=174.72, Price=23.39, SOC=0.40  |  After Action: Action=2.00, Reward=-6.43e+01, New SOC=0.50
#
# Step 51:
#   Before Action: Demand=172.80, Price=19.96, SOC=0.50  |  After Action: Action=1.00, Reward=-3.45e+01, New SOC=0.50
#
# Step 52:
#   Before Action: Demand=169.92, Price=20.02, SOC=0.50  |  After Action: Action=0.00, Reward=-1.40e+01, New SOC=0.40
#
# Step 53:
#   Before Action: Demand=164.16, Price=19.91, SOC=0.40  |  After Action: Action=2.00, Reward=-5.26e+01, New SOC=0.50
#
# Step 54:
#   Before Action: Demand=169.92, Price=22.09, SOC=0.50  |  After Action: Action=1.00, Reward=-3.75e+01, New SOC=0.50
#
# Step 55:
#   Before Action: Demand=168.00, Price=25.15, SOC=0.50  |  After Action: Action=0.00, Reward=-1.71e+01, New SOC=0.40
#
# Step 56:
#   Before Action: Demand=208.32, Price=28.50, SOC=0.40  |  After Action: Action=0.00, Reward=-3.09e+01, New SOC=0.30
#
# Step 57:
#   Before Action: Demand=384.00, Price=30.77, SOC=0.30  |  After Action: Action=1.00, Reward=-1.18e+02, New SOC=0.30
#
# Step 58:
#   Before Action: Demand=602.88, Price=44.15, SOC=0.30  |  After Action: Action=0.00, Reward=-2.22e+02, New SOC=0.20
#
# Step 59:
#   Before Action: Demand=884.16, Price=53.39, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 60:
#   Before Action: Demand=935.04, Price=60.24, SOC=0.10  |  After Action: Action=2.00, Reward=-6.24e+02, New SOC=0.20
#
# Step 61:
#   Before Action: Demand=901.44, Price=102.53, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 62:
#   Before Action: Demand=913.92, Price=68.63, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 63:
#   Before Action: Demand=956.16, Price=63.87, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 64:
#   Before Action: Demand=913.92, Price=44.28, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 65:
#   Before Action: Demand=963.84, Price=50.70, SOC=0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 66:
#   Before Action: Demand=969.60, Price=49.15, SOC=0.10  |  After Action: Action=2.00, Reward=-5.26e+02, New SOC=0.20
#
# Step 67:
#   Before Action: Demand=829.44, Price=37.79, SOC=0.20  |  After Action: Action=2.00, Reward=-3.51e+02, New SOC=0.30
#
# Step 68:
#   Before Action: Demand=569.28, Price=49.50, SOC=0.30  |  After Action: Action=1.00, Reward=-2.82e+02, New SOC=0.30
#
# Step 69:
#   Before Action: Demand=439.68, Price=31.22, SOC=0.30  |  After Action: Action=1.00, Reward=-1.37e+02, New SOC=0.30
#
# Step 70:
#   Before Action: Demand=319.68, Price=40.39, SOC=0.30  |  After Action: Action=1.00, Reward=-1.29e+02, New SOC=0.30
#
# Step 71:
#   Before Action: Demand=268.80, Price=27.31, SOC=0.30  |  After Action: Action=1.00, Reward=-7.34e+01, New SOC=0.30
#
# Step 72:
#   Before Action: Demand=201.60, Price=26.45, SOC=0.30  |  After Action: Action=1.00, Reward=-5.33e+01, New SOC=0.30
#
# Step 73:
#   Before Action: Demand=188.16, Price=26.21, SOC=0.30  |  After Action: Action=1.00, Reward=-4.93e+01, New SOC=0.30
#
# Step 74:
#   Before Action: Demand=179.52, Price=26.31, SOC=0.30  |  After Action: Action=1.00, Reward=-4.72e+01, New SOC=0.30
#
# Step 75:
#   Before Action: Demand=172.80, Price=23.63, SOC=0.30  |  After Action: Action=0.00, Reward=-1.72e+01, New SOC=0.20
#
# Step 76:
#   Before Action: Demand=167.04, Price=21.52, SOC=0.20  |  After Action: Action=2.00, Reward=-5.75e+01, New SOC=0.30
#
# Step 77:
#   Before Action: Demand=171.84, Price=21.06, SOC=0.30  |  After Action: Action=1.00, Reward=-3.62e+01, New SOC=0.30
#
# Step 78:
#   Before Action: Demand=164.16, Price=20.82, SOC=0.30  |  After Action: Action=1.00, Reward=-3.42e+01, New SOC=0.30
#
# Step 79:
#   Before Action: Demand=161.28, Price=20.34, SOC=0.30  |  After Action: Action=1.00, Reward=-3.28e+01, New SOC=0.30
#
# Step 80:
#   Before Action: Demand=212.16, Price=22.23, SOC=0.30  |  After Action: Action=0.00, Reward=-2.49e+01, New SOC=0.20
#
# Step 81:
#   Before Action: Demand=386.88, Price=31.91, SOC=0.20  |  After Action: Action=1.00, Reward=-1.23e+02, New SOC=0.20
#
# Step 82:
#   Before Action: Demand=647.04, Price=35.59, SOC=0.20  |  After Action: Action=2.00, Reward=-2.66e+02, New SOC=0.30
#
# Step 83:
#   Before Action: Demand=955.20, Price=58.93, SOC=0.30  |  After Action: Action=2.00, Reward=-6.22e+02, New SOC=0.40
#
# Step 84:
#   Before Action: Demand=963.84, Price=72.28, SOC=0.40  |  After Action: Action=1.00, Reward=-6.97e+02, New SOC=0.40
#
# Step 85:
#   Before Action: Demand=899.52, Price=66.18, SOC=0.40  |  After Action: Action=2.00, Reward=-6.61e+02, New SOC=0.50
#
# Step 86:
#   Before Action: Demand=912.96, Price=43.44, SOC=0.50  |  After Action: Action=2.00, Reward=-4.40e+02, New SOC=0.60
#
# Step 87:
#   Before Action: Demand=976.32, Price=38.83, SOC=0.60  |  After Action: Action=2.00, Reward=-4.18e+02, New SOC=0.70
#
# Step 88:
#   Before Action: Demand=1012.80, Price=38.33, SOC=0.70  |  After Action: Action=0.00, Reward=-3.50e+02, New SOC=0.60
#
# Step 89:
#   Before Action: Demand=960.96, Price=40.57, SOC=0.60  |  After Action: Action=0.00, Reward=-3.49e+02, New SOC=0.50
#
# Step 90:
#   Before Action: Demand=941.76, Price=46.73, SOC=0.50  |  After Action: Action=1.00, Reward=-4.40e+02, New SOC=0.50
#
# Step 91:
#   Before Action: Demand=768.00, Price=37.84, SOC=0.50  |  After Action: Action=0.00, Reward=-2.53e+02, New SOC=0.40
#
# Step 92:
#   Before Action: Demand=533.76, Price=53.31, SOC=0.40  |  After Action: Action=2.00, Reward=-3.38e+02, New SOC=0.50
#
# Step 93:
#   Before Action: Demand=387.84, Price=41.95, SOC=0.50  |  After Action: Action=0.00, Reward=-1.21e+02, New SOC=0.40
#
# Step 94:
#   Before Action: Demand=315.84, Price=31.88, SOC=0.40  |  After Action: Action=0.00, Reward=-6.88e+01, New SOC=0.30
#
# Step 95:
#   Before Action: Demand=265.92, Price=28.73, SOC=0.30  |  After Action: Action=2.00, Reward=-1.05e+02, New SOC=0.40
#
# Step 96:
#   Before Action: Demand=237.12, Price=27.39, SOC=0.40  |  After Action: Action=1.00, Reward=-6.49e+01, New SOC=0.40
#
# Step 97:
#   Before Action: Demand=200.64, Price=22.41, SOC=0.40  |  After Action: Action=0.00, Reward=-2.26e+01, New SOC=0.30
#
# Step 98:
#   Before Action: Demand=187.20, Price=22.48, SOC=0.30  |  After Action: Action=1.00, Reward=-4.21e+01, New SOC=0.30
#
# Step 99:
#   Before Action: Demand=176.64, Price=20.58, SOC=0.30  |  After Action: Action=2.00, Reward=-5.69e+01, New SOC=0.40
#
# Step 100:
#   Before Action: Demand=176.64, Price=20.10, SOC=0.40  |  After Action: Action=0.00, Reward=-1.54e+01, New SOC=0.30
#
# Step 101:
#   Before Action: Demand=174.72, Price=20.20, SOC=0.30  |  After Action: Action=0.00, Reward=-1.51e+01, New SOC=0.20
#
# Step 102:
#   Before Action: Demand=172.80, Price=22.15, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 103:
#   Before Action: Demand=176.64, Price=24.97, SOC=0.10  |  After Action: Action=2.00, Reward=-6.91e+01, New SOC=0.20
#
# Step 104:
#   Before Action: Demand=215.04, Price=27.13, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 105:
#   Before Action: Demand=351.36, Price=39.86, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 106:
#   Before Action: Demand=571.20, Price=99.62, SOC=0.00  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 107:
#   Before Action: Demand=787.20, Price=37.47, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 108:
#   Before Action: Demand=845.76, Price=47.43, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 109:
#   Before Action: Demand=893.76, Price=69.60, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 110:
#   Before Action: Demand=900.48, Price=69.31, SOC=-0.10  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 111:
#   Before Action: Demand=957.12, Price=46.47, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 112:
#   Before Action: Demand=936.96, Price=64.27, SOC=0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 113:
#   Before Action: Demand=882.24, Price=78.02, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 114:
#   Before Action: Demand=825.60, Price=62.20, SOC=0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 115:
#   Before Action: Demand=664.32, Price=36.58, SOC=0.10  |  After Action: Action=2.00, Reward=-2.80e+02, New SOC=0.20
#
# Step 116:
#   Before Action: Demand=486.72, Price=33.90, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 117:
#   Before Action: Demand=349.44, Price=55.03, SOC=0.10  |  After Action: Action=2.00, Reward=-2.47e+02, New SOC=0.20
#
# Step 118:
#   Before Action: Demand=305.28, Price=65.42, SOC=0.20  |  After Action: Action=2.00, Reward=-2.65e+02, New SOC=0.30
#
# Step 119:
#   Before Action: Demand=257.28, Price=29.26, SOC=0.30  |  After Action: Action=2.00, Reward=-1.05e+02, New SOC=0.40
#
# Step 120:
#   Before Action: Demand=223.68, Price=27.46, SOC=0.40  |  After Action: Action=1.00, Reward=-6.14e+01, New SOC=0.40
#
# Step 121:
#   Before Action: Demand=182.40, Price=29.20, SOC=0.40  |  After Action: Action=1.00, Reward=-5.33e+01, New SOC=0.40
#
# Step 122:
#   Before Action: Demand=177.60, Price=26.13, SOC=0.40  |  After Action: Action=2.00, Reward=-7.25e+01, New SOC=0.50
#
# Step 123:
#   Before Action: Demand=172.80, Price=23.82, SOC=0.50  |  After Action: Action=2.00, Reward=-6.50e+01, New SOC=0.60
#
# Step 124:
#   Before Action: Demand=171.84, Price=24.00, SOC=0.60  |  After Action: Action=1.00, Reward=-4.12e+01, New SOC=0.60
#
# Step 125:
#   Before Action: Demand=176.64, Price=23.26, SOC=0.60  |  After Action: Action=2.00, Reward=-6.43e+01, New SOC=0.70
#
# Step 126:
#   Before Action: Demand=172.80, Price=25.68, SOC=0.70  |  After Action: Action=0.00, Reward=-1.87e+01, New SOC=0.60
#
# Step 127:
#   Before Action: Demand=171.84, Price=24.59, SOC=0.60  |  After Action: Action=0.00, Reward=-1.77e+01, New SOC=0.50
#
# Step 128:
#   Before Action: Demand=229.44, Price=25.16, SOC=0.50  |  After Action: Action=1.00, Reward=-5.77e+01, New SOC=0.50
#
# Step 129:
#   Before Action: Demand=384.96, Price=26.68, SOC=0.50  |  After Action: Action=0.00, Reward=-7.60e+01, New SOC=0.40
#
# Step 130:
#   Before Action: Demand=546.24, Price=32.49, SOC=0.40  |  After Action: Action=2.00, Reward=-2.10e+02, New SOC=0.50
#
# Step 131:
#   Before Action: Demand=751.68, Price=27.16, SOC=0.50  |  After Action: Action=0.00, Reward=-1.77e+02, New SOC=0.40
#
# Step 132:
#   Before Action: Demand=774.72, Price=28.14, SOC=0.40  |  After Action: Action=0.00, Reward=-1.90e+02, New SOC=0.30
#
# Step 133:
#   Before Action: Demand=767.04, Price=34.19, SOC=0.30  |  After Action: Action=1.00, Reward=-2.62e+02, New SOC=0.30
#
# Step 134:
#   Before Action: Demand=775.68, Price=32.44, SOC=0.30  |  After Action: Action=2.00, Reward=-2.84e+02, New SOC=0.40
#
# Step 135:
#   Before Action: Demand=842.88, Price=36.09, SOC=0.40  |  After Action: Action=0.00, Reward=-2.68e+02, New SOC=0.30
#
# Step 136:
#   Before Action: Demand=784.32, Price=42.63, SOC=0.30  |  After Action: Action=0.00, Reward=-2.92e+02, New SOC=0.20
#
# Step 137:
#   Before Action: Demand=805.44, Price=38.36, SOC=0.20  |  After Action: Action=1.00, Reward=-3.09e+02, New SOC=0.20
#
# Step 138:
#   Before Action: Demand=738.24, Price=35.79, SOC=0.20  |  After Action: Action=2.00, Reward=-3.00e+02, New SOC=0.30
#
# Step 139:
#   Before Action: Demand=619.20, Price=28.37, SOC=0.30  |  After Action: Action=0.00, Reward=-1.47e+02, New SOC=0.20
#
# Step 140:
#   Before Action: Demand=453.12, Price=24.66, SOC=0.20  |  After Action: Action=2.00, Reward=-1.36e+02, New SOC=0.30
#
# Step 141:
#   Before Action: Demand=342.72, Price=21.21, SOC=0.30  |  After Action: Action=1.00, Reward=-7.27e+01, New SOC=0.30
#
# Step 142:
#   Before Action: Demand=275.52, Price=22.05, SOC=0.30  |  After Action: Action=0.00, Reward=-3.87e+01, New SOC=0.20
#
# Step 143:
#   Before Action: Demand=241.92, Price=21.35, SOC=0.20  |  After Action: Action=1.00, Reward=-5.16e+01, New SOC=0.20
#
# Step 144:
#   Before Action: Demand=197.76, Price=18.79, SOC=0.20  |  After Action: Action=1.00, Reward=-3.72e+01, New SOC=0.20
#
# Step 145:
#   Before Action: Demand=178.56, Price=18.39, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 146:
#   Before Action: Demand=176.64, Price=18.24, SOC=0.10  |  After Action: Action=2.00, Reward=-5.05e+01, New SOC=0.20
#
# Step 147:
#   Before Action: Demand=172.80, Price=17.43, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 148:
#   Before Action: Demand=166.08, Price=16.69, SOC=0.10  |  After Action: Action=2.00, Reward=-4.44e+01, New SOC=0.20
#
# Step 149:
#   Before Action: Demand=166.08, Price=14.70, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 150:
#   Before Action: Demand=166.08, Price=6.88, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 151:
#   Before Action: Demand=163.20, Price=7.43, SOC=0.00  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 152:
#   Before Action: Demand=171.84, Price=11.13, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 153:
#   Before Action: Demand=182.40, Price=18.85, SOC=-0.10  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 154:
#   Before Action: Demand=205.44, Price=18.90, SOC=0.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=0.00
#
# Step 155:
#   Before Action: Demand=277.44, Price=19.82, SOC=0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 156:
#   Before Action: Demand=306.24, Price=23.92, SOC=0.10  |  After Action: Action=2.00, Reward=-9.72e+01, New SOC=0.20
#
# Step 157:
#   Before Action: Demand=337.92, Price=22.03, SOC=0.20  |  After Action: Action=2.00, Reward=-9.65e+01, New SOC=0.30
#
# Step 158:
#   Before Action: Demand=345.60, Price=25.36, SOC=0.30  |  After Action: Action=1.00, Reward=-8.76e+01, New SOC=0.30
#
# Step 159:
#   Before Action: Demand=352.32, Price=23.61, SOC=0.30  |  After Action: Action=2.00, Reward=-1.07e+02, New SOC=0.40
#
# Step 160:
#   Before Action: Demand=353.28, Price=25.82, SOC=0.40  |  After Action: Action=1.00, Reward=-9.12e+01, New SOC=0.40
#
# Step 161:
#   Before Action: Demand=341.76, Price=46.36, SOC=0.40  |  After Action: Action=1.00, Reward=-1.58e+02, New SOC=0.40
#
# Step 162:
#   Before Action: Demand=288.00, Price=35.01, SOC=0.40  |  After Action: Action=1.00, Reward=-1.01e+02, New SOC=0.40
#
# Step 163:
#   Before Action: Demand=245.76, Price=33.89, SOC=0.40  |  After Action: Action=0.00, Reward=-4.94e+01, New SOC=0.30
#
# Step 164:
#   Before Action: Demand=239.04, Price=25.43, SOC=0.30  |  After Action: Action=0.00, Reward=-3.54e+01, New SOC=0.20
#
# Step 165:
#   Before Action: Demand=222.72, Price=21.93, SOC=0.20  |  After Action: Action=1.00, Reward=-4.88e+01, New SOC=0.20
#
# Step 166:
#   Before Action: Demand=212.16, Price=21.84, SOC=0.20  |  After Action: Action=2.00, Reward=-6.82e+01, New SOC=0.30
#
# Step 167:
#   Before Action: Demand=196.80, Price=19.56, SOC=0.30  |  After Action: Action=2.00, Reward=-5.81e+01, New SOC=0.40
#
# Step 168:
#   Before Action: Demand=189.12, Price=18.67, SOC=0.40  |  After Action: Action=1.00, Reward=-3.53e+01, New SOC=0.40
#
# Step 169:
#   Before Action: Demand=181.44, Price=16.62, SOC=0.40  |  After Action: Action=0.00, Reward=-1.35e+01, New SOC=0.30
#
# Step 170:
#   Before Action: Demand=171.84, Price=16.03, SOC=0.30  |  After Action: Action=1.00, Reward=-2.75e+01, New SOC=0.30
#
# Step 171:
#   Before Action: Demand=172.80, Price=15.49, SOC=0.30  |  After Action: Action=1.00, Reward=-2.68e+01, New SOC=0.30
#
# Step 172:
#   Before Action: Demand=165.12, Price=8.66, SOC=0.30  |  After Action: Action=1.00, Reward=-1.43e+01, New SOC=0.30
#
# Step 173:
#   Before Action: Demand=162.24, Price=11.00, SOC=0.30  |  After Action: Action=2.00, Reward=-2.88e+01, New SOC=0.40
#
# Step 174:
#   Before Action: Demand=163.20, Price=9.75, SOC=0.40  |  After Action: Action=2.00, Reward=-2.57e+01, New SOC=0.50
#
# Step 175:
#   Before Action: Demand=160.32, Price=-10.99, SOC=0.50  |  After Action: Action=2.00, Reward=2.86e+01, New SOC=0.60
#
# Step 176:
#   Before Action: Demand=156.48, Price=14.33, SOC=0.60  |  After Action: Action=1.00, Reward=-2.24e+01, New SOC=0.60
#
# Step 177:
#   Before Action: Demand=155.52, Price=16.35, SOC=0.60  |  After Action: Action=1.00, Reward=-2.54e+01, New SOC=0.60
#
# Step 178:
#   Before Action: Demand=153.60, Price=18.45, SOC=0.60  |  After Action: Action=1.00, Reward=-2.83e+01, New SOC=0.60
#
# Step 179:
#   Before Action: Demand=172.80, Price=20.20, SOC=0.60  |  After Action: Action=0.00, Reward=-1.47e+01, New SOC=0.50
#
# Step 180:
#   Before Action: Demand=176.64, Price=21.35, SOC=0.50  |  After Action: Action=1.00, Reward=-3.77e+01, New SOC=0.50
#
# Step 181:
#   Before Action: Demand=163.20, Price=24.63, SOC=0.50  |  After Action: Action=0.00, Reward=-1.56e+01, New SOC=0.40
#
# Step 182:
#   Before Action: Demand=173.76, Price=27.09, SOC=0.40  |  After Action: Action=0.00, Reward=-2.00e+01, New SOC=0.30
#
# Step 183:
#   Before Action: Demand=197.76, Price=26.47, SOC=0.30
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:141: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\utils\passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
#   |  After Action: Action=0.00, Reward=-2.59e+01, New SOC=0.20
#
# Step 184:
#   Before Action: Demand=229.44, Price=32.72, SOC=0.20  |  After Action: Action=2.00, Reward=-1.08e+02, New SOC=0.30
#
# Step 185:
#   Before Action: Demand=220.80, Price=42.02, SOC=0.30  |  After Action: Action=1.00, Reward=-9.28e+01, New SOC=0.30
#
# Step 186:
#   Before Action: Demand=224.64, Price=56.96, SOC=0.30  |  After Action: Action=1.00, Reward=-1.28e+02, New SOC=0.30
#
# Step 187:
#   Before Action: Demand=225.60, Price=61.93, SOC=0.30  |  After Action: Action=2.00, Reward=-2.02e+02, New SOC=0.40
#
# Step 188:
#   Before Action: Demand=212.16, Price=49.03, SOC=0.40  |  After Action: Action=2.00, Reward=-1.53e+02, New SOC=0.50
#
# Step 189:
#   Before Action: Demand=207.36, Price=35.50, SOC=0.50  |  After Action: Action=0.00, Reward=-3.81e+01, New SOC=0.40
#
# Step 190:
#   Before Action: Demand=210.24, Price=27.83, SOC=0.40  |  After Action: Action=0.00, Reward=-3.07e+01, New SOC=0.30
#
# Step 191:
#   Before Action: Demand=216.00, Price=24.06, SOC=0.30  |  After Action: Action=0.00, Reward=-2.79e+01, New SOC=0.20
#
# Step 192:
#   Before Action: Demand=189.12, Price=21.40, SOC=0.20  |  After Action: Action=2.00, Reward=-6.19e+01, New SOC=0.30
#
# Step 193:
#   Before Action: Demand=172.80, Price=18.80, SOC=0.30  |  After Action: Action=0.00, Reward=-1.37e+01, New SOC=0.20
#
# Step 194:
#   Before Action: Demand=165.12, Price=17.96, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 195:
#   Before Action: Demand=162.24, Price=17.22, SOC=0.10  |  After Action: Action=2.00, Reward=-4.52e+01, New SOC=0.20
#
# Step 196:
#   Before Action: Demand=162.24, Price=16.03, SOC=0.20  |  After Action: Action=2.00, Reward=-4.20e+01, New SOC=0.30
#
# Step 197:
#   Before Action: Demand=161.28, Price=16.57, SOC=0.30  |  After Action: Action=0.00, Reward=-1.02e+01, New SOC=0.20
#
# Step 198:
#   Before Action: Demand=163.20, Price=17.52, SOC=0.20  |  After Action: Action=1.00, Reward=-2.86e+01, New SOC=0.20
#
# Step 199:
#   Before Action: Demand=168.96, Price=17.91, SOC=0.20  |  After Action: Action=2.00, Reward=-4.82e+01, New SOC=0.30
#
# Step 200:
#   Before Action: Demand=221.76, Price=19.05, SOC=0.30  |  After Action: Action=1.00, Reward=-4.22e+01, New SOC=0.30
#
# Step 201:
#   Before Action: Demand=363.84, Price=21.21, SOC=0.30  |  After Action: Action=0.00, Reward=-5.60e+01, New SOC=0.20
#
# Step 202:
#   Before Action: Demand=615.36, Price=25.24, SOC=0.20  |  After Action: Action=1.00, Reward=-1.55e+02, New SOC=0.20
#
# Step 203:
#   Before Action: Demand=772.80, Price=47.94, SOC=0.20  |  After Action: Action=2.00, Reward=-4.18e+02, New SOC=0.30
#
# Step 204:
#   Before Action: Demand=764.16, Price=24.35, SOC=0.30  |  After Action: Action=1.00, Reward=-1.86e+02, New SOC=0.30
#
# Step 205:
#   Before Action: Demand=762.24, Price=29.21, SOC=0.30  |  After Action: Action=0.00, Reward=-1.93e+02, New SOC=0.20
#
# Step 206:
#   Before Action: Demand=730.56, Price=37.11, SOC=0.20  |  After Action: Action=1.00, Reward=-2.71e+02, New SOC=0.20
#
# Step 207:
#   Before Action: Demand=779.52, Price=45.54, SOC=0.20  |  After Action: Action=1.00, Reward=-3.55e+02, New SOC=0.20
#
# Step 208:
#   Before Action: Demand=775.68, Price=69.17, SOC=0.20  |  After Action: Action=1.00, Reward=-5.37e+02, New SOC=0.20
#
# Step 209:
#   Before Action: Demand=785.28, Price=75.06, SOC=0.20  |  After Action: Action=1.00, Reward=-5.89e+02, New SOC=0.20
#
# Step 210:
#   Before Action: Demand=748.80, Price=89.49, SOC=0.20  |  After Action: Action=1.00, Reward=-6.70e+02, New SOC=0.20
#
# Step 211:
#   Before Action: Demand=652.80, Price=62.21, SOC=0.20  |  After Action: Action=2.00, Reward=-4.68e+02, New SOC=0.30
#
# Step 212:
#   Before Action: Demand=502.08, Price=36.59, SOC=0.30  |  After Action: Action=2.00, Reward=-2.20e+02, New SOC=0.40
#
# Step 213:
#   Before Action: Demand=394.56, Price=28.71, SOC=0.40  |  After Action: Action=2.00, Reward=-1.42e+02, New SOC=0.50
#
# Step 214:
#   Before Action: Demand=303.36, Price=29.38, SOC=0.50  |  After Action: Action=1.00, Reward=-8.91e+01, New SOC=0.50
#
# Step 215:
#   Before Action: Demand=241.92, Price=24.38, SOC=0.50  |  After Action: Action=0.00, Reward=-3.46e+01, New SOC=0.40
#
# Step 216:
#   Before Action: Demand=198.72, Price=24.86, SOC=0.40  |  After Action: Action=2.00, Reward=-7.43e+01, New SOC=0.50
#
# Step 217:
#   Before Action: Demand=176.64, Price=19.65, SOC=0.50  |  After Action: Action=2.00, Reward=-5.44e+01, New SOC=0.60
#
# Step 218:
#   Before Action: Demand=169.92, Price=19.11, SOC=0.60  |  After Action: Action=1.00, Reward=-3.25e+01, New SOC=0.60
#
# Step 219:
#   Before Action: Demand=165.12, Price=18.31, SOC=0.60  |  After Action: Action=0.00, Reward=-1.19e+01, New SOC=0.50
#
# Step 220:
#   Before Action: Demand=161.28, Price=17.15, SOC=0.50  |  After Action: Action=2.00, Reward=-4.48e+01, New SOC=0.60
#
# Step 221:
#   Before Action: Demand=165.12, Price=17.45, SOC=0.60  |  After Action: Action=0.00, Reward=-1.14e+01, New SOC=0.50
#
# Step 222:
#   Before Action: Demand=162.24, Price=18.70, SOC=0.50  |  After Action: Action=1.00, Reward=-3.03e+01, New SOC=0.50
#
# Step 223:
#   Before Action: Demand=163.20, Price=19.39, SOC=0.50  |  After Action: Action=2.00, Reward=-5.10e+01, New SOC=0.60
#
# Step 224:
#   Before Action: Demand=204.48, Price=20.97, SOC=0.60  |  After Action: Action=0.00, Reward=-2.19e+01, New SOC=0.50
#
# Step 225:
#   Before Action: Demand=328.32, Price=28.75, SOC=0.50  |  After Action: Action=2.00, Reward=-1.23e+02, New SOC=0.60
#
# Step 226:
#   Before Action: Demand=567.36, Price=34.74, SOC=0.60  |  After Action: Action=1.00, Reward=-1.97e+02, New SOC=0.60
#
# Step 227:
#   Before Action: Demand=781.44, Price=52.25, SOC=0.60  |  After Action: Action=0.00, Reward=-3.56e+02, New SOC=0.50
#
# Step 228:
#   Before Action: Demand=816.00, Price=34.13, SOC=0.50  |  After Action: Action=2.00, Reward=-3.13e+02, New SOC=0.60
#
# Step 229:
#   Before Action: Demand=797.76, Price=38.11, SOC=0.60  |  After Action: Action=0.00, Reward=-2.66e+02, New SOC=0.50
#
# Step 230:
#   Before Action: Demand=839.04, Price=40.78, SOC=0.50  |  After Action: Action=1.00, Reward=-3.42e+02, New SOC=0.50
#
# Step 231:
#   Before Action: Demand=870.72, Price=52.84, SOC=0.50  |  After Action: Action=0.00, Reward=-4.07e+02, New SOC=0.40
#
# Step 232:
#   Before Action: Demand=841.92, Price=110.44, SOC=0.40  |  After Action: Action=0.00, Reward=-8.19e+02, New SOC=0.30
#
# Step 233:
#   Before Action: Demand=840.96, Price=44.70, SOC=0.30  |  After Action: Action=1.00, Reward=-3.76e+02, New SOC=0.30
#
# Step 234:
#   Before Action: Demand=802.56, Price=67.98, SOC=0.30  |  After Action: Action=2.00, Reward=-6.14e+02, New SOC=0.40
#
# Step 235:
#   Before Action: Demand=663.36, Price=53.66, SOC=0.40  |  After Action: Action=2.00, Reward=-4.10e+02, New SOC=0.50
#
# Step 236:
#   Before Action: Demand=504.00, Price=40.78, SOC=0.50  |  After Action: Action=0.00, Reward=-1.65e+02, New SOC=0.40
#
# Step 237:
#   Before Action: Demand=387.84, Price=39.84, SOC=0.40  |  After Action: Action=1.00, Reward=-1.55e+02, New SOC=0.40
#
# Step 238:
#   Before Action: Demand=319.68, Price=37.24, SOC=0.40  |  After Action: Action=1.00, Reward=-1.19e+02, New SOC=0.40
#
# Step 239:
#   Before Action: Demand=254.40, Price=29.92, SOC=0.40  |  After Action: Action=1.00, Reward=-7.61e+01, New SOC=0.40
#
# Step 240:
#   Before Action: Demand=225.60, Price=26.35, SOC=0.40  |  After Action: Action=2.00, Reward=-8.58e+01, New SOC=0.50
#
# Step 241:
#   Before Action: Demand=195.84, Price=23.53, SOC=0.50  |  After Action: Action=2.00, Reward=-6.96e+01, New SOC=0.60
#
# Step 242:
#   Before Action: Demand=193.92, Price=22.66, SOC=0.60  |  After Action: Action=2.00, Reward=-6.66e+01, New SOC=0.70
#
# Step 243:
#   Before Action: Demand=190.08, Price=20.46, SOC=0.70  |  After Action: Action=2.00, Reward=-5.94e+01, New SOC=0.80
#
# Step 244:
#   Before Action: Demand=189.12, Price=19.77, SOC=0.80  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 245:
#   Before Action: Demand=184.32, Price=19.82, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 246:
#   Before Action: Demand=189.12, Price=21.03, SOC=1.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 247:
#   Before Action: Demand=190.08, Price=24.17, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 248:
#   Before Action: Demand=229.44, Price=68.48, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 249:
#   Before Action: Demand=377.28, Price=26.96, SOC=1.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 250:
#   Before Action: Demand=596.16, Price=27.26, SOC=1.00  |  After Action: Action=1.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 251:
#   Before Action: Demand=826.56, Price=31.44, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 252:
#   Before Action: Demand=865.92, Price=31.05, SOC=0.90  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 253:
#   Before Action: Demand=847.68, Price=34.47, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 254:
#   Before Action: Demand=885.12, Price=32.35, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 255:
#   Before Action: Demand=960.00, Price=102.56, SOC=0.90  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 256:
#   Before Action: Demand=957.12, Price=55.66, SOC=0.90  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 257:
#   Before Action: Demand=923.52, Price=43.90, SOC=0.90  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 258:
#   Before Action: Demand=901.44, Price=49.20, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 259:
#   Before Action: Demand=790.08, Price=57.30, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 260:
#   Before Action: Demand=547.20, Price=30.25, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 261:
#   Before Action: Demand=430.08, Price=29.31, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 262:
#   Before Action: Demand=317.76, Price=30.92, SOC=0.90  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 263:
#   Before Action: Demand=280.32, Price=26.10, SOC=0.90  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 264:
#   Before Action: Demand=245.76, Price=24.87, SOC=1.00  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=1.10
#
# Step 265:
#   Before Action: Demand=216.96, Price=23.15, SOC=1.10  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=1.20
#
# Step 266:
#   Before Action: Demand=216.96, Price=21.09, SOC=1.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=1.20
#
# Step 267:
#   Before Action: Demand=208.32, Price=19.65, SOC=1.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=1.20
#
# Step 268:
#   Before Action: Demand=192.96, Price=18.93, SOC=1.20  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=1.10
#
# Step 269:
#   Before Action: Demand=191.04, Price=18.75, SOC=1.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 270:
#   Before Action: Demand=193.92, Price=19.57, SOC=1.00  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=1.10
#
# Step 271:
#   Before Action: Demand=189.12, Price=20.83, SOC=1.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=1.10
#
# Step 272:
#   Before Action: Demand=229.44, Price=24.12, SOC=1.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=1.00
#
# Step 273:
#   Before Action: Demand=420.48, Price=25.86, SOC=1.00  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.90
#
# Step 274:
#   Before Action: Demand=648.00, Price=29.12, SOC=0.90  |  After Action: Action=0.00, Reward=-1.60e+02, New SOC=0.80
#
# Step 275:
#   Before Action: Demand=901.44, Price=33.69, SOC=0.80  |  After Action: Action=0.00, Reward=-2.70e+02, New SOC=0.70
#
# Step 276:
#   Before Action: Demand=896.64, Price=34.62, SOC=0.70  |  After Action: Action=0.00, Reward=-2.76e+02, New SOC=0.60
#
# Step 277:
#   Before Action: Demand=870.72, Price=35.60, SOC=0.60  |  After Action: Action=0.00, Reward=-2.74e+02, New SOC=0.50
#
# Step 278:
#   Before Action: Demand=877.44, Price=37.37, SOC=0.50  |  After Action: Action=0.00, Reward=-2.91e+02, New SOC=0.40
#
# Step 279:
#   Before Action: Demand=926.40, Price=41.02, SOC=0.40  |  After Action: Action=1.00, Reward=-3.80e+02, New SOC=0.40
#
# Step 280:
#   Before Action: Demand=908.16, Price=39.79, SOC=0.40  |  After Action: Action=2.00, Reward=-4.01e+02, New SOC=0.50
#
# Step 281:
#   Before Action: Demand=903.36, Price=39.05, SOC=0.50  |  After Action: Action=0.00, Reward=-3.14e+02, New SOC=0.40
#
# Step 282:
#   Before Action: Demand=894.72, Price=42.66, SOC=0.40  |  After Action: Action=1.00, Reward=-3.82e+02, New SOC=0.40
#
# Step 283:
#   Before Action: Demand=746.88, Price=35.37, SOC=0.40  |  After Action: Action=1.00, Reward=-2.64e+02, New SOC=0.40
#
# Step 284:
#   Before Action: Demand=579.84, Price=34.10, SOC=0.40  |  After Action: Action=2.00, Reward=-2.32e+02, New SOC=0.50
#
# Step 285:
#   Before Action: Demand=431.04, Price=35.62, SOC=0.50  |  After Action: Action=1.00, Reward=-1.54e+02, New SOC=0.50
#
# Step 286:
#   Before Action: Demand=338.88, Price=32.81, SOC=0.50  |  After Action: Action=0.00, Reward=-7.84e+01, New SOC=0.40
#
# Step 287:
#   Before Action: Demand=273.60, Price=29.05, SOC=0.40  |  After Action: Action=2.00, Reward=-1.09e+02, New SOC=0.50
#
# Step 288:
# ...
#   Before Action: Demand=1440.00, Price=46.24, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 878:
#   Before Action: Demand=1384.32, Price=45.20, SOC=-0.30  |  After Action: Action=1.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 879:
#   Before Action: Demand=1515.84, Price=41.32, SOC=-0.30  |  After Action: Action=1.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 880:
#   Before Action: Demand=1367.04, Price=42.22, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 881:
#   Before Action: Demand=1443.84, Price=48.22, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 882:
#   Before Action: Demand=1427.52, Price=58.04, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 883:
#   Before Action: Demand=1229.76, Price=45.76, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 884:
#   Before Action: Demand=815.04, Price=34.24, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 885:
#   Before Action: Demand=582.72, Price=34.06, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 886:
#   Before Action: Demand=394.56, Price=32.88, SOC=-0.30  |  After Action: Action=0.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 887:
#   Before Action: Demand=294.72, Price=29.14, SOC=-0.40  |  After Action: Action=2.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 888:
#   Before Action: Demand=268.80, Price=27.61, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 889:
#   Before Action: Demand=216.96, Price=23.42, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 890:
#   Before Action: Demand=188.16, Price=21.43, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 891:
#   Before Action: Demand=180.48, Price=20.90, SOC=-0.10  |  After Action: Action=1.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 892:
#   Before Action: Demand=174.72, Price=19.87, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 893:
#   Before Action: Demand=174.72, Price=19.96, SOC=-0.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 894:
#   Before Action: Demand=180.48, Price=21.87, SOC=-0.20  |  After Action: Action=2.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 895:
#   Before Action: Demand=181.44, Price=25.67, SOC=-0.10  |  After Action: Action=2.00, Reward=-3.00e+04, New SOC=-0.00
#
# Step 896:
#   Before Action: Demand=301.44, Price=26.71, SOC=-0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 897:
#   Before Action: Demand=530.88, Price=23.75, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=-0.00
#
# Step 898:
#   Before Action: Demand=972.48, Price=37.75, SOC=-0.00  |  After Action: Action=2.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 899:
#   Before Action: Demand=1302.72, Price=30.85, SOC=0.10  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 900:
#   Before Action: Demand=1382.40, Price=34.35, SOC=0.10  |  After Action: Action=2.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 901:
#   Before Action: Demand=1331.52, Price=39.96, SOC=0.20  |  After Action: Action=1.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 902:
#   Before Action: Demand=1299.84, Price=40.76, SOC=0.20  |  After Action: Action=2.00, Reward=-5.71e+02, New SOC=0.30
#
# Step 903:
#   Before Action: Demand=1364.16, Price=44.67, SOC=0.30  |  After Action: Action=0.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 904:
#   Before Action: Demand=1431.36, Price=41.55, SOC=0.20  |  After Action: Action=1.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 905:
#   Before Action: Demand=1414.08, Price=43.86, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 906:
#   Before Action: Demand=1348.80, Price=35.46, SOC=0.10  |  After Action: Action=1.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 907:
#   Before Action: Demand=1153.92, Price=36.31, SOC=0.10  |  After Action: Action=2.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 908:
#   Before Action: Demand=784.32, Price=36.83, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 909:
#   Before Action: Demand=573.12, Price=35.55, SOC=0.10  |  After Action: Action=2.00, Reward=-1.00e+04, New SOC=0.20
#
# Step 910:
#   Before Action: Demand=434.88, Price=30.48, SOC=0.20  |  After Action: Action=0.00, Reward=-1.50e+04, New SOC=0.10
#
# Step 911:
#   Before Action: Demand=349.44, Price=27.42, SOC=0.10  |  After Action: Action=0.00, Reward=-3.00e+04, New SOC=-0.00
#
# Step 912:
#   Before Action: Demand=285.12, Price=24.39, SOC=-0.00  |  After Action: Action=0.00, Reward=-5.50e+04, New SOC=-0.10
#
# Step 913:
#   Before Action: Demand=240.96, Price=22.69, SOC=-0.10  |  After Action: Action=0.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 914:
#   Before Action: Demand=232.32, Price=22.28, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 915:
#   Before Action: Demand=212.16, Price=21.25, SOC=-0.30  |  After Action: Action=2.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 916:
#   Before Action: Demand=212.16, Price=20.61, SOC=-0.20  |  After Action: Action=1.00, Reward=-9.00e+04, New SOC=-0.20
#
# Step 917:
#   Before Action: Demand=202.56, Price=20.55, SOC=-0.20  |  After Action: Action=0.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 918:
#   Before Action: Demand=206.40, Price=20.55, SOC=-0.30  |  After Action: Action=0.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 919:
#   Before Action: Demand=211.20, Price=27.61, SOC=-0.40  |  After Action: Action=2.00, Reward=-1.35e+05, New SOC=-0.30
#
# Step 920:
#   Before Action: Demand=263.04, Price=25.05, SOC=-0.30  |  After Action: Action=0.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 921:
#   Before Action: Demand=540.48, Price=23.99, SOC=-0.40  |  After Action: Action=1.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 922:
#   Before Action: Demand=916.80, Price=27.23, SOC=-0.40  |  After Action: Action=1.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 923:
#   Before Action: Demand=1277.76, Price=30.93, SOC=-0.40  |  After Action: Action=1.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 924:
#   Before Action: Demand=1309.44, Price=34.55, SOC=-0.40  |  After Action: Action=0.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 925:
#   Before Action: Demand=1258.56, Price=34.48, SOC=-0.50  |  After Action: Action=2.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 926:
#   Before Action: Demand=1238.40, Price=43.70, SOC=-0.40  |  After Action: Action=0.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 927:
#   Before Action: Demand=1274.88, Price=38.11, SOC=-0.50  |  After Action: Action=2.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 928:
#   Before Action: Demand=1265.28, Price=52.37, SOC=-0.40  |  After Action: Action=0.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 929:
#   Before Action: Demand=1291.20, Price=64.64, SOC=-0.50  |  After Action: Action=0.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 930:
#   Before Action: Demand=1225.92, Price=48.48, SOC=-0.60  |  After Action: Action=1.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 931:
#   Before Action: Demand=1106.88, Price=45.62, SOC=-0.60  |  After Action: Action=2.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 932:
#   Before Action: Demand=736.32, Price=49.19, SOC=-0.50  |  After Action: Action=1.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 933:
#   Before Action: Demand=515.52, Price=49.56, SOC=-0.50  |  After Action: Action=1.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 934:
#   Before Action: Demand=364.80, Price=34.52, SOC=-0.50  |  After Action: Action=1.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 935:
#   Before Action: Demand=330.24, Price=30.70, SOC=-0.50  |  After Action: Action=2.00, Reward=-1.90e+05, New SOC=-0.40
#
# Step 936:
#   Before Action: Demand=284.16, Price=27.04, SOC=-0.40  |  After Action: Action=0.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 937:
#   Before Action: Demand=222.72, Price=25.21, SOC=-0.50  |  After Action: Action=0.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 938:
#   Before Action: Demand=209.28, Price=24.21, SOC=-0.60  |  After Action: Action=1.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 939:
#   Before Action: Demand=193.92, Price=22.25, SOC=-0.60  |  After Action: Action=0.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 940:
#   Before Action: Demand=191.04, Price=21.42, SOC=-0.70  |  After Action: Action=1.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 941:
#   Before Action: Demand=186.24, Price=21.64, SOC=-0.70  |  After Action: Action=0.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 942:
#   Before Action: Demand=184.32, Price=23.10, SOC=-0.80  |  After Action: Action=2.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 943:
#   Before Action: Demand=200.64, Price=25.38, SOC=-0.70  |  After Action: Action=1.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 944:
#   Before Action: Demand=261.12, Price=24.15, SOC=-0.70  |  After Action: Action=2.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 945:
#   Before Action: Demand=508.80, Price=24.16, SOC=-0.60  |  After Action: Action=1.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 946:
#   Before Action: Demand=901.44, Price=34.01, SOC=-0.60  |  After Action: Action=2.00, Reward=-2.55e+05, New SOC=-0.50
#
# Step 947:
#   Before Action: Demand=1237.44, Price=31.15, SOC=-0.50  |  After Action: Action=0.00, Reward=-3.30e+05, New SOC=-0.60
#
# Step 948:
#   Before Action: Demand=1222.08, Price=35.77, SOC=-0.60  |  After Action: Action=0.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 949:
#   Before Action: Demand=1170.24, Price=33.88, SOC=-0.70  |  After Action: Action=0.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 950:
#   Before Action: Demand=1128.96, Price=40.10, SOC=-0.80  |  After Action: Action=1.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 951:
#   Before Action: Demand=1242.24, Price=58.22, SOC=-0.80  |  After Action: Action=2.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 952:
#   Before Action: Demand=1175.04, Price=56.90, SOC=-0.70  |  After Action: Action=0.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 953:
#   Before Action: Demand=1200.00, Price=56.85, SOC=-0.80  |  After Action: Action=1.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 954:
#   Before Action: Demand=1147.20, Price=46.73, SOC=-0.80  |  After Action: Action=2.00, Reward=-4.15e+05, New SOC=-0.70
#
# Step 955:
#   Before Action: Demand=936.00, Price=41.86, SOC=-0.70  |  After Action: Action=0.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 956:
#   Before Action: Demand=646.08, Price=34.56, SOC=-0.80  |  After Action: Action=0.00, Reward=-6.15e+05, New SOC=-0.90
#
# Step 957:
#   Before Action: Demand=497.28, Price=34.01, SOC=-0.90  |  After Action: Action=0.00, Reward=-7.30e+05, New SOC=-1.00
#
# Step 958:
#   Before Action: Demand=377.28, Price=31.50, SOC=-1.00  |  After Action: Action=2.00, Reward=-6.15e+05, New SOC=-0.90
#
# Step 959:
#   Before Action: Demand=337.92, Price=25.80, SOC=-0.90  |  After Action: Action=1.00, Reward=-6.15e+05, New SOC=-0.90
#
# Step 960:
#   Before Action: Demand=266.88, Price=24.33, SOC=-0.90  |  After Action: Action=2.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 961:
#   Before Action: Demand=215.04, Price=21.88, SOC=-0.80  |  After Action: Action=1.00, Reward=-5.10e+05, New SOC=-0.80
#
# Step 962:
#   Before Action: Demand=200.64, Price=21.44, SOC=-0.80  |  After Action: Action=0.00, Reward=-6.15e+05, New SOC=-0.90
#
# Step 963:
#   Before Action: Demand=197.76, Price=20.39, SOC=-0.90  |  After Action: Action=0.00, Reward=-7.30e+05, New SOC=-1.00
#
# Step 964:
#   Before Action: Demand=195.84, Price=20.01, SOC=-1.00  |  After Action: Action=0.00, Reward=-8.55e+05, New SOC=-1.10
#
# Step 965:
#   Before Action: Demand=190.08, Price=20.22, SOC=-1.10  |  After Action: Action=1.00, Reward=-8.55e+05, New SOC=-1.10
#
# Step 966:
#   Before Action: Demand=194.88, Price=21.04, SOC=-1.10  |  After Action: Action=1.00, Reward=-8.55e+05, New SOC=-1.10
#
# Step 967:
#   Before Action: Demand=194.88, Price=22.22, SOC=-1.10  |  After Action: Action=0.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 968:
#   Before Action: Demand=278.40, Price=23.69, SOC=-1.20  |  After Action: Action=1.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 969:
#   Before Action: Demand=480.00, Price=26.48, SOC=-1.20  |  After Action: Action=0.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 970:
#   Before Action: Demand=841.92, Price=32.08, SOC=-1.30  |  After Action: Action=0.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 971:
#   Before Action: Demand=1204.80, Price=36.96, SOC=-1.40  |  After Action: Action=2.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 972:
#   Before Action: Demand=1235.52, Price=36.86, SOC=-1.30  |  After Action: Action=2.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 973:
#   Before Action: Demand=1151.04, Price=36.06, SOC=-1.20  |  After Action: Action=0.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 974:
#   Before Action: Demand=1122.24, Price=35.93, SOC=-1.30  |  After Action: Action=0.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 975:
#   Before Action: Demand=1233.60, Price=48.82, SOC=-1.40  |  After Action: Action=2.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 976:
#   Before Action: Demand=1197.12, Price=38.65, SOC=-1.30  |  After Action: Action=0.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 977:
#   Before Action: Demand=1183.68, Price=42.28, SOC=-1.40  |  After Action: Action=2.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 978:
#   Before Action: Demand=1177.92, Price=60.12, SOC=-1.30  |  After Action: Action=2.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 979:
#   Before Action: Demand=969.60, Price=35.49, SOC=-1.20  |  After Action: Action=0.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 980:
#   Before Action: Demand=628.80, Price=35.30, SOC=-1.30  |  After Action: Action=0.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 981:
#   Before Action: Demand=456.00, Price=33.61, SOC=-1.40  |  After Action: Action=1.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 982:
#   Before Action: Demand=354.24, Price=32.18, SOC=-1.40  |  After Action: Action=0.00, Reward=-1.46e+06, New SOC=-1.50
#
# Step 983:
#   Before Action: Demand=304.32, Price=27.48, SOC=-1.50  |  After Action: Action=0.00, Reward=-1.63e+06, New SOC=-1.60
#
# Step 984:
#   Before Action: Demand=240.00, Price=27.07, SOC=-1.60  |  After Action: Action=2.00, Reward=-1.46e+06, New SOC=-1.50
#
# Step 985:
#   Before Action: Demand=218.88, Price=24.83, SOC=-1.50  |  After Action: Action=2.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 986:
#   Before Action: Demand=219.84, Price=22.79, SOC=-1.40  |  After Action: Action=2.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 987:
#   Before Action: Demand=186.24, Price=22.00, SOC=-1.30  |  After Action: Action=1.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 988:
#   Before Action: Demand=183.36, Price=20.63, SOC=-1.30  |  After Action: Action=1.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 989:
#   Before Action: Demand=181.44, Price=20.91, SOC=-1.30  |  After Action: Action=1.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 990:
#   Before Action: Demand=180.48, Price=21.21, SOC=-1.30  |  After Action: Action=1.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 991:
#   Before Action: Demand=190.08, Price=22.12, SOC=-1.30  |  After Action: Action=2.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 992:
#   Before Action: Demand=226.56, Price=23.97, SOC=-1.20  |  After Action: Action=0.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 993:
#   Before Action: Demand=282.24, Price=24.98, SOC=-1.30  |  After Action: Action=2.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 994:
#   Before Action: Demand=311.04, Price=27.84, SOC=-1.20  |  After Action: Action=1.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 995:
#   Before Action: Demand=352.32, Price=28.99, SOC=-1.20  |  After Action: Action=1.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 996:
#   Before Action: Demand=405.12, Price=32.68, SOC=-1.20  |  After Action: Action=1.00, Reward=-9.90e+05, New SOC=-1.20
#
# Step 997:
#   Before Action: Demand=427.20, Price=67.47, SOC=-1.20  |  After Action: Action=0.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 998:
#   Before Action: Demand=412.80, Price=33.23, SOC=-1.30  |  After Action: Action=1.00, Reward=-1.14e+06, New SOC=-1.30
#
# Step 999:
#   Before Action: Demand=410.88, Price=49.43, SOC=-1.30  |  After Action: Action=0.00, Reward=-1.29e+06, New SOC=-1.40
#
# Step 1000:
#   Before Action: Demand=396.48, Price=51.18, SOC=-1.40  |  After Action: Action=0.00, Reward=-1.46e+06, New SOC=-1.50

# %%
# Assuming you have already registered the new environment with the id 'EnergyManagement-v0'
env = gym.make('EnergyManagement-v0')

# Run a simulation loop
observation = env.reset()
for t in range(1000):
    # Print information before and after taking action
    print(f"Step {t + 1}:")

    # Before Action
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")

    # Take an action predicted by the model
    action, _states = model.predict(observation)

    # Perform the action in the environment
    observation, reward, done, _ = env.step(action)

    # After Action
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()

# %% [markdown]
# ##### SAC

# %%
import gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = SAC("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("sac_energy_management")
print("Training Done")
# Out:
#   Cell In[4], line 2
#     from stable_baselines3 import SACcommand:cellOutput.enableScrolling?a7293a47-b59e-4ce6-90bc-076e8bdd9fe4
#                                                                                       ^
# SyntaxError: invalid decimal literal

# %%
import gym
from stable_baselines3 import SAC
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

env = gym.make(env_id)
model = SAC.load("sac_energy_management")

observation = env.reset()
for t in range(1000):
    print(f"Step {t + 1}:")
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")
    action, _states = model.predict(observation)
    observation, reward, done, _ = env.step(action)
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()
# Out:
# Step 1:
#   Before Action: Demand=632.88, Price=22.77, SOC=0.50  |  After Action: Action=-0.10, Reward=-1.21e+02, New SOC=0.40
#
# Step 2:
#   Before Action: Demand=546.84, Price=22.95, SOC=0.40  |  After Action: Action=-0.10, Reward=-1.03e+02, New SOC=0.30
#
# Step 3:
#   Before Action: Demand=494.46, Price=20.45, SOC=0.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=0.20
#
# Step 4:
#   Before Action: Demand=541.08, Price=19.80, SOC=0.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=0.10
#
# Step 5:
#   Before Action: Demand=533.70, Price=18.78, SOC=0.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.00
#
# Step 6:
#   Before Action: Demand=519.12, Price=17.63, SOC=-0.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.10
#
# Step 7:
#   Before Action: Demand=618.48, Price=20.81, SOC=-0.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.20
#
# Step 8:
#   Before Action: Demand=725.76, Price=21.61, SOC=-0.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.30
#
# Step 9:
#   Before Action: Demand=774.72, Price=22.38, SOC=-0.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.40
#
# Step 10:
#   Before Action: Demand=688.14, Price=25.72, SOC=-0.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.50
#
# Step 11:
#   Before Action: Demand=637.38, Price=29.87, SOC=-0.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.60
#
# Step 12:
#   Before Action: Demand=626.76, Price=29.82, SOC=-0.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.70
#
# Step 13:
#   Before Action: Demand=630.54, Price=64.36, SOC=-0.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.80
#
# Step 14:
#   Before Action: Demand=669.96, Price=39.83, SOC=-0.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-0.90
#
# Step 15:
#   Before Action: Demand=610.56, Price=43.39, SOC=-0.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.00
#
# Step 16:
#   Before Action: Demand=611.64, Price=32.77, SOC=-1.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.10
#
# Step 17:
#   Before Action: Demand=624.42, Price=30.72, SOC=-1.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.20
#
# Step 18:
#   Before Action: Demand=658.26, Price=54.12, SOC=-1.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.30
#
# Step 19:
#   Before Action: Demand=770.58, Price=51.37, SOC=-1.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.40
#
# Step 20:
#   Before Action: Demand=821.88, Price=29.45, SOC=-1.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.50
#
# Step 21:
#   Before Action: Demand=884.52, Price=27.19, SOC=-1.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.60
#
# Step 22:
#   Before Action: Demand=863.82, Price=26.87, SOC=-1.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.70
#
# Step 23:
#   Before Action: Demand=833.76, Price=23.74, SOC=-1.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.80
#
# Step 24:
#   Before Action: Demand=752.76, Price=21.84, SOC=-1.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-1.90
#
# Step 25:
#   Before Action: Demand=669.78, Price=20.44, SOC=-1.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.00
#
# Step 26:
#   Before Action: Demand=574.20, Price=21.09, SOC=-2.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.10
#
# Step 27:
#   Before Action: Demand=519.30, Price=19.75, SOC=-2.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.20
#
# Step 28:
#   Before Action: Demand=551.34, Price=18.20, SOC=-2.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.30
#
# Step 29:
#   Before Action: Demand=524.52, Price=16.90, SOC=-2.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.40
#
# Step 30:
#   Before Action: Demand=508.14, Price=15.10, SOC=-2.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.50
#
# Step 31:
#   Before Action: Demand=556.92, Price=16.79, SOC=-2.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.60
#
# Step 32:
#   Before Action: Demand=654.30, Price=20.54, SOC=-2.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.70
#
# Step 33:
#   Before Action: Demand=783.36, Price=21.04, SOC=-2.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.80
#
# Step 34:
#   Before Action: Demand=760.50, Price=24.23, SOC=-2.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-2.90
#
# Step 35:
#   Before Action: Demand=750.06, Price=27.70, SOC=-2.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.00
#
# Step 36:
#   Before Action: Demand=744.66, Price=31.67, SOC=-3.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.10
#
# Step 37:
#   Before Action: Demand=729.72, Price=33.65, SOC=-3.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.20
#
# Step 38:
#   Before Action: Demand=782.46, Price=30.80, SOC=-3.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.30
#
# Step 39:
#   Before Action: Demand=707.04, Price=49.25, SOC=-3.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.40
#
# Step 40:
#   Before Action: Demand=711.72, Price=52.82, SOC=-3.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.50
#
# Step 41:
#   Before Action: Demand=703.62, Price=74.72, SOC=-3.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.60
#
# Step 42:
#   Before Action: Demand=730.44, Price=82.84, SOC=-3.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.70
#
# Step 43:
#   Before Action: Demand=817.20, Price=34.16, SOC=-3.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.80
#
# Step 44:
#   Before Action: Demand=831.96, Price=33.79, SOC=-3.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-3.90
#
# Step 45:
#   Before Action: Demand=871.38, Price=32.59, SOC=-3.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.00
#
# Step 46:
#   Before Action: Demand=853.74, Price=37.68, SOC=-4.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.10
#
# Step 47:
#   Before Action: Demand=819.00, Price=24.41, SOC=-4.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.20
#
# Step 48:
#   Before Action: Demand=754.56, Price=23.60, SOC=-4.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.30
#
# Step 49:
#   Before Action: Demand=673.38, Price=22.86, SOC=-4.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.40
#
# Step 50:
#   Before Action: Demand=577.44, Price=20.83, SOC=-4.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.50
#
# Step 51:
#   Before Action: Demand=523.26, Price=19.59, SOC=-4.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.60
#
# Step 52:
#   Before Action: Demand=524.34, Price=18.31, SOC=-4.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.70
#
# Step 53:
#   Before Action: Demand=552.06, Price=18.60, SOC=-4.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.80
#
# Step 54:
#   Before Action: Demand=491.40, Price=19.60, SOC=-4.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-4.90
#
# Step 55:
#   Before Action: Demand=539.64, Price=20.78, SOC=-4.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.00
#
# Step 56:
#   Before Action: Demand=625.86, Price=21.63, SOC=-5.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.10
#
# Step 57:
#   Before Action: Demand=752.04, Price=24.38, SOC=-5.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.20
#
# Step 58:
#   Before Action: Demand=763.92, Price=30.60, SOC=-5.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.30
#
# Step 59:
#   Before Action: Demand=770.22, Price=31.13, SOC=-5.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.40
#
# Step 60:
#   Before Action: Demand=741.42, Price=32.07, SOC=-5.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.50
#
# Step 61:
#   Before Action: Demand=756.90, Price=73.07, SOC=-5.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.60
#
# Step 62:
#   Before Action: Demand=804.78, Price=31.79, SOC=-5.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.70
#
# Step 63:
#   Before Action: Demand=724.14, Price=36.43, SOC=-5.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.80
#
# Step 64:
#   Before Action: Demand=718.38, Price=40.57, SOC=-5.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-5.90
#
# Step 65:
#   Before Action: Demand=728.46, Price=60.37, SOC=-5.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.00
#
# Step 66:
#   Before Action: Demand=777.60, Price=40.44, SOC=-6.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.10
#
# Step 67:
#   Before Action: Demand=869.40, Price=33.28, SOC=-6.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.20
#
# Step 68:
#   Before Action: Demand=916.92, Price=30.53, SOC=-6.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.30
#
# Step 69:
#   Before Action: Demand=951.84, Price=30.45, SOC=-6.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.40
#
# Step 70:
#   Before Action: Demand=936.18, Price=28.20, SOC=-6.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.50
#
# Step 71:
#   Before Action: Demand=870.66, Price=25.55, SOC=-6.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.60
#
# Step 72:
#   Before Action: Demand=767.16, Price=23.76, SOC=-6.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.70
#
# Step 73:
#   Before Action: Demand=645.66, Price=22.97, SOC=-6.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.80
#
# Step 74:
#   Before Action: Demand=557.10, Price=21.59, SOC=-6.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-6.90
#
# Step 75:
#   Before Action: Demand=507.78, Price=20.95, SOC=-6.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.00
#
# Step 76:
#   Before Action: Demand=544.32, Price=17.63, SOC=-7.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.10
#
# Step 77:
#   Before Action: Demand=525.42, Price=19.27, SOC=-7.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.20
#
# Step 78:
#   Before Action: Demand=520.20, Price=19.76, SOC=-7.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.30
#
# Step 79:
#   Before Action: Demand=630.36, Price=17.64, SOC=-7.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.40
#
# Step 80:
#   Before Action: Demand=738.90, Price=20.16, SOC=-7.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.50
#
# Step 81:
#   Before Action: Demand=795.24, Price=20.72, SOC=-7.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.60
#
# Step 82:
#   Before Action: Demand=687.24, Price=22.26, SOC=-7.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.70
#
# Step 83:
#   Before Action: Demand=636.84, Price=25.72, SOC=-7.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.80
#
# Step 84:
#   Before Action: Demand=617.22, Price=59.95, SOC=-7.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-7.90
#
# Step 85:
#   Before Action: Demand=614.16, Price=56.68, SOC=-7.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.00
#
# Step 86:
#   Before Action: Demand=654.66, Price=36.51, SOC=-8.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.10
#
# Step 87:
#   Before Action: Demand=604.26, Price=39.46, SOC=-8.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.20
#
# Step 88:
#   Before Action: Demand=624.06, Price=34.25, SOC=-8.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.30
#
# Step 89:
#   Before Action: Demand=630.18, Price=32.59, SOC=-8.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.40
#
# Step 90:
#   Before Action: Demand=683.46, Price=40.89, SOC=-8.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.50
#
# Step 91:
#   Before Action: Demand=816.66, Price=28.11, SOC=-8.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.60
#
# Step 92:
#   Before Action: Demand=880.56, Price=26.02, SOC=-8.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.70
#
# Step 93:
#   Before Action: Demand=900.18, Price=24.28, SOC=-8.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.80
#
# Step 94:
#   Before Action: Demand=876.06, Price=23.29, SOC=-8.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-8.90
#
# Step 95:
#   Before Action: Demand=824.94, Price=22.57, SOC=-8.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.00
#
# Step 96:
#   Before Action: Demand=735.66, Price=21.00, SOC=-9.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.10
#
# Step 97:
#   Before Action: Demand=617.40, Price=19.51, SOC=-9.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.20
#
# Step 98:
#   Before Action: Demand=545.76, Price=19.96, SOC=-9.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.30
#
# Step 99:
#   Before Action: Demand=497.70, Price=17.19, SOC=-9.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.40
#
# Step 100:
#   Before Action: Demand=508.68, Price=16.09, SOC=-9.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.50
#
# Step 101:
#   Before Action: Demand=558.00, Price=16.93, SOC=-9.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.60
#
# Step 102:
#   Before Action: Demand=510.84, Price=18.48, SOC=-9.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.70
#
# Step 103:
#   Before Action: Demand=624.06, Price=21.35, SOC=-9.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.80
#
# Step 104:
#   Before Action: Demand=745.74, Price=21.35, SOC=-9.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-9.90
#
# Step 105:
#   Before Action: Demand=784.80, Price=23.36, SOC=-9.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.00
#
# Step 106:
#   Before Action: Demand=708.66, Price=25.87, SOC=-10.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.10
#
# Step 107:
#   Before Action: Demand=633.06, Price=28.66, SOC=-10.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.20
#
# Step 108:
#   Before Action: Demand=625.86, Price=51.98, SOC=-10.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.30
#
# Step 109:
#   Before Action: Demand=648.00, Price=52.38, SOC=-10.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.40
#
# Step 110:
#   Before Action: Demand=670.68, Price=67.58, SOC=-10.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.50
#
# Step 111:
#   Before Action: Demand=615.06, Price=41.14, SOC=-10.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.60
#
# Step 112:
#   Before Action: Demand=615.06, Price=33.76, SOC=-10.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.70
#
# Step 113:
#   Before Action: Demand=636.48, Price=38.90, SOC=-10.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.80
#
# Step 114:
#   Before Action: Demand=669.60, Price=35.55, SOC=-10.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-10.90
#
# Step 115:
#   Before Action: Demand=804.42, Price=34.62, SOC=-10.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.00
#
# Step 116:
#   Before Action: Demand=815.76, Price=28.78, SOC=-11.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.10
#
# Step 117:
#   Before Action: Demand=872.10, Price=29.76, SOC=-11.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.20
#
# Step 118:
#   Before Action: Demand=871.56, Price=28.89, SOC=-11.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.30
#
# Step 119:
#   Before Action: Demand=835.92, Price=24.96, SOC=-11.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.40
#
# Step 120:
#   Before Action: Demand=781.92, Price=23.62, SOC=-11.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.50
#
# Step 121:
#   Before Action: Demand=671.22, Price=21.09, SOC=-11.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.60
#
# Step 122:
#   Before Action: Demand=580.86, Price=20.71, SOC=-11.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.70
#
# Step 123:
#   Before Action: Demand=526.14, Price=20.09, SOC=-11.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.80
#
# Step 124:
#   Before Action: Demand=567.18, Price=19.15, SOC=-11.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-11.90
#
# Step 125:
#   Before Action: Demand=517.68, Price=19.37, SOC=-11.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.00
#
# Step 126:
#   Before Action: Demand=502.38, Price=21.56, SOC=-12.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.10
#
# Step 127:
#   Before Action: Demand=559.80, Price=22.01, SOC=-12.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.20
#
# Step 128:
#   Before Action: Demand=649.26, Price=22.93, SOC=-12.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.30
#
# Step 129:
#   Before Action: Demand=780.66, Price=24.25, SOC=-12.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.40
#
# Step 130:
#   Before Action: Demand=774.54, Price=25.40, SOC=-12.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.50
#
# Step 131:
#   Before Action: Demand=771.30, Price=29.79, SOC=-12.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.60
#
# Step 132:
#   Before Action: Demand=762.48, Price=29.19, SOC=-12.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.70
#
# Step 133:
#   Before Action: Demand=777.42, Price=31.67, SOC=-12.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.80
#
# Step 134:
#   Before Action: Demand=804.42, Price=37.03, SOC=-12.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-12.90
#
# Step 135:
#   Before Action: Demand=752.04, Price=58.91, SOC=-12.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.00
#
# Step 136:
#   Before Action: Demand=708.30, Price=93.48, SOC=-13.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.10
#
# Step 137:
#   Before Action: Demand=712.80, Price=34.92, SOC=-13.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.20
#
# Step 138:
#   Before Action: Demand=755.10, Price=36.96, SOC=-13.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.30
#
# Step 139:
#   Before Action: Demand=880.92, Price=41.68, SOC=-13.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.40
#
# Step 140:
#   Before Action: Demand=893.34, Price=36.61, SOC=-13.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.50
#
# Step 141:
#   Before Action: Demand=937.44, Price=28.57, SOC=-13.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.60
#
# Step 142:
#   Before Action: Demand=937.80, Price=29.99, SOC=-13.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.70
#
# Step 143:
#   Before Action: Demand=876.06, Price=24.44, SOC=-13.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.80
#
# Step 144:
#   Before Action: Demand=759.06, Price=22.36, SOC=-13.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-13.90
#
# Step 145:
#   Before Action: Demand=639.18, Price=20.13, SOC=-13.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.00
#
# Step 146:
#   Before Action: Demand=550.80, Price=20.42, SOC=-14.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.10
#
# Step 147:
#   Before Action: Demand=501.12, Price=18.98, SOC=-14.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.20
#
# Step 148:
#   Before Action: Demand=553.50, Price=18.49, SOC=-14.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.30
#
# Step 149:
#   Before Action: Demand=530.46, Price=18.12, SOC=-14.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.40
#
# Step 150:
#   Before Action: Demand=516.78, Price=20.71, SOC=-14.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.50
#
# Step 151:
#   Before Action: Demand=627.30, Price=21.45, SOC=-14.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.60
#
# Step 152:
#   Before Action: Demand=741.60, Price=22.53, SOC=-14.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.70
#
# Step 153:
#   Before Action: Demand=796.32, Price=22.81, SOC=-14.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.80
#
# Step 154:
#   Before Action: Demand=677.88, Price=25.72, SOC=-14.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-14.90
#
# Step 155:
#   Before Action: Demand=632.52, Price=27.37, SOC=-14.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.00
#
# Step 156:
#   Before Action: Demand=623.70, Price=44.27, SOC=-15.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.10
#
# Step 157:
#   Before Action: Demand=624.96, Price=29.55, SOC=-15.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.20
#
# Step 158:
#   Before Action: Demand=674.64, Price=30.82, SOC=-15.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.30
#
# Step 159:
#   Before Action: Demand=604.44, Price=30.45, SOC=-15.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.40
#
# Step 160:
#   Before Action: Demand=621.18, Price=33.09, SOC=-15.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.50
#
# Step 161:
#   Before Action: Demand=641.16, Price=39.88, SOC=-15.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.60
#
# Step 162:
#   Before Action: Demand=682.20, Price=42.73, SOC=-15.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.70
#
# Step 163:
#   Before Action: Demand=817.92, Price=31.42, SOC=-15.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.80
#
# Step 164:
#   Before Action: Demand=853.74, Price=27.66, SOC=-15.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-15.90
#
# Step 165:
#   Before Action: Demand=894.06, Price=26.86, SOC=-15.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.00
#
# Step 166:
#   Before Action: Demand=896.94, Price=25.56, SOC=-16.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.10
#
# Step 167:
#   Before Action: Demand=853.56, Price=22.41, SOC=-16.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.20
#
# Step 168:
#   Before Action: Demand=764.10, Price=19.61, SOC=-16.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.30
#
# Step 169:
#   Before Action: Demand=632.70, Price=19.79, SOC=-16.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.40
#
# Step 170:
#   Before Action: Demand=549.54, Price=19.01, SOC=-16.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.50
#
# Step 171:
#   Before Action: Demand=502.20, Price=17.92, SOC=-16.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.60
#
# Step 172:
#   Before Action: Demand=544.68, Price=16.89, SOC=-16.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.70
#
# Step 173:
#   Before Action: Demand=517.86, Price=16.48, SOC=-16.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.80
#
# Step 174:
#   Before Action: Demand=512.28, Price=16.27, SOC=-16.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-16.90
#
# Step 175:
#   Before Action: Demand=623.52, Price=16.42, SOC=-16.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.00
#
# Step 176:
#   Before Action: Demand=749.52, Price=18.81, SOC=-17.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.10
#
# Step 177:
#   Before Action: Demand=790.56, Price=20.95, SOC=-17.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.20
#
# Step 178:
#   Before Action: Demand=681.84, Price=22.12, SOC=-17.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.30
#
# Step 179:
#   Before Action: Demand=623.52, Price=25.35, SOC=-17.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.40
#
# Step 180:
#   Before Action: Demand=606.78, Price=26.44, SOC=-17.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.50
#
# Step 181:
#   Before Action: Demand=606.24, Price=26.86, SOC=-17.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.60
#
# Step 182:
#   Before Action: Demand=659.52, Price=30.54, SOC=-17.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.70
#
# Step 183:
#   Before Action: Demand=603.18, Price=29.97, SOC=-17.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.80
#
# Step 184:
#   Before Action: Demand=610.74, Price=30.46, SOC=-17.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-17.90
#
# Step 185:
#   Before Action: Demand=629.82, Price=58.93, SOC=-17.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.00
#
# Step 186:
#   Before Action: Demand=667.08, Price=37.83, SOC=-18.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.10
#
# Step 187:
#   Before Action: Demand=795.42, Price=47.29, SOC=-18.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.20
#
# Step 188:
#   Before Action: Demand=832.14, Price=37.58, SOC=-18.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.30
#
# Step 189:
#   Before Action: Demand=857.52, Price=24.33, SOC=-18.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.40
#
# Step 190:
#   Before Action: Demand=858.24, Price=24.47, SOC=-18.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.50
#
# Step 191:
#   Before Action: Demand=833.94, Price=22.21, SOC=-18.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.60
#
# Step 192:
#   Before Action: Demand=776.88, Price=20.49, SOC=-18.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.70
#
# Step 193:
#   Before Action: Demand=687.96, Price=20.95, SOC=-18.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.80
#
# Step 194:
#   Before Action: Demand=590.04, Price=19.67, SOC=-18.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-18.90
#
# Step 195:
#   Before Action: Demand=522.90, Price=18.20, SOC=-18.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.00
#
# Step 196:
#   Before Action: Demand=549.54, Price=17.64, SOC=-19.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.10
#
# Step 197:
#   Before Action: Demand=541.08, Price=15.28, SOC=-19.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.20
#
# Step 198:
#   Before Action: Demand=506.52, Price=13.84, SOC=-19.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.30
#
# Step 199:
#   Before Action: Demand=572.58, Price=12.31, SOC=-19.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.40
#
# Step 200:
#   Before Action: Demand=661.14, Price=17.37, SOC=-19.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.50
#
# Step 201:
#   Before Action: Demand=757.98, Price=17.10, SOC=-19.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.60
#
# Step 202:
#   Before Action: Demand=775.26, Price=20.64, SOC=-19.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.70
#
# Step 203:
#   Before Action: Demand=749.34, Price=20.66, SOC=-19.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.80
#
# Step 204:
#   Before Action: Demand=752.04, Price=22.09, SOC=-19.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-19.90
#
# Step 205:
#   Before Action: Demand=746.10, Price=23.49, SOC=-19.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.00
#
# Step 206:
#   Before Action: Demand=797.40, Price=25.67, SOC=-20.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.10
#
# Step 207:
#   Before Action: Demand=721.98, Price=26.53, SOC=-20.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.20
#
# Step 208:
#   Before Action: Demand=705.60, Price=28.20, SOC=-20.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.30
#
# Step 209:
#   Before Action: Demand=712.80, Price=29.88, SOC=-20.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.40
#
# Step 210:
#   Before Action: Demand=767.70, Price=36.03, SOC=-20.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.50
#
# Step 211:
#   Before Action: Demand=906.30, Price=30.08, SOC=-20.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.60
#
# Step 212:
#   Before Action: Demand=902.34, Price=28.48, SOC=-20.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.70
#
# Step 213:
#   Before Action: Demand=907.38, Price=25.17, SOC=-20.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.80
#
# Step 214:
#   Before Action: Demand=891.90, Price=24.63, SOC=-20.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-20.90
#
# Step 215:
#   Before Action: Demand=835.92, Price=21.83, SOC=-20.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.00
#
# Step 216:
#   Before Action: Demand=766.08, Price=18.46, SOC=-21.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.10
#
# Step 217:
#   Before Action: Demand=663.66, Price=16.81, SOC=-21.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.20
#
# Step 218:
#   Before Action: Demand=580.86, Price=15.14, SOC=-21.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.30
#
# Step 219:
#   Before Action: Demand=524.88, Price=14.37, SOC=-21.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.40
#
# Step 220:
#   Before Action: Demand=556.56, Price=13.72, SOC=-21.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.50
#
# Step 221:
#   Before Action: Demand=518.40, Price=14.23, SOC=-21.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.60
#
# Step 222:
#   Before Action: Demand=500.04, Price=17.02, SOC=-21.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.70
#
# Step 223:
#   Before Action: Demand=535.14, Price=16.71, SOC=-21.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.80
#
# Step 224:
#   Before Action: Demand=613.44, Price=18.78, SOC=-21.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-21.90
#
# Step 225:
#   Before Action: Demand=753.30, Price=19.17, SOC=-21.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.00
#
# Step 226:
#   Before Action: Demand=759.24, Price=22.48, SOC=-22.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.10
#
# Step 227:
#   Before Action: Demand=759.42, Price=25.01, SOC=-22.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.20
#
# Step 228:
#   Before Action: Demand=735.66, Price=25.31, SOC=-22.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.30
#
# Step 229:
#   Before Action: Demand=732.96, Price=27.99, SOC=-22.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.40
#
# Step 230:
#   Before Action: Demand=779.94, Price=30.39, SOC=-22.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.50
#
# Step 231:
#   Before Action: Demand=740.70, Price=31.50, SOC=-22.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.60
#
# Step 232:
#   Before Action: Demand=706.86, Price=48.66, SOC=-22.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.70
#
# Step 233:
#   Before Action: Demand=738.36, Price=46.91, SOC=-22.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.80
#
# Step 234:
#   Before Action: Demand=808.56, Price=111.63, SOC=-22.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-22.90
#
# Step 235:
#   Before Action: Demand=951.66, Price=52.61, SOC=-22.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.00
#
# Step 236:
#   Before Action: Demand=925.92, Price=34.99, SOC=-23.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.10
#
# Step 237:
#   Before Action: Demand=942.48, Price=36.41, SOC=-23.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.20
#
# Step 238:
#   Before Action: Demand=910.62, Price=29.73, SOC=-23.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.30
#
# Step 239:
#   Before Action: Demand=865.44, Price=25.64, SOC=-23.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.40
#
# Step 240:
#   Before Action: Demand=743.22, Price=22.50, SOC=-23.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.50
#
# Step 241:
#   Before Action: Demand=627.48, Price=19.95, SOC=-23.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.60
#
# Step 242:
#   Before Action: Demand=540.72, Price=20.32, SOC=-23.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.70
#
# Step 243:
#   Before Action: Demand=497.34, Price=19.22, SOC=-23.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.80
#
# Step 244:
#   Before Action: Demand=539.64, Price=18.60, SOC=-23.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-23.90
#
# Step 245:
#   Before Action: Demand=525.78, Price=18.71, SOC=-23.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.00
#
# Step 246:
#   Before Action: Demand=512.64, Price=20.37, SOC=-24.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.10
#
# Step 247:
#   Before Action: Demand=635.22, Price=21.31, SOC=-24.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.20
#
# Step 248:
#   Before Action: Demand=734.58, Price=23.36, SOC=-24.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.30
#
# Step 249:
#   Before Action: Demand=783.90, Price=25.60, SOC=-24.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.40
#
# Step 250:
#   Before Action: Demand=674.46, Price=26.17, SOC=-24.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.50
#
# Step 251:
#   Before Action: Demand=640.80, Price=27.14, SOC=-24.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.60
#
# Step 252:
#   Before Action: Demand=635.94, Price=29.54, SOC=-24.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.70
#
# Step 253:
#   Before Action: Demand=634.32, Price=32.70, SOC=-24.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.80
#
# Step 254:
#   Before Action: Demand=683.28, Price=31.68, SOC=-24.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-24.90
#
# Step 255:
#   Before Action: Demand=615.78, Price=38.02, SOC=-24.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.00
#
# Step 256:
#   Before Action: Demand=628.02, Price=41.51, SOC=-25.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.10
#
# Step 257:
#   Before Action: Demand=652.50, Price=40.46, SOC=-25.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.20
#
# Step 258:
#   Before Action: Demand=710.46, Price=35.56, SOC=-25.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.30
#
# Step 259:
#   Before Action: Demand=847.98, Price=36.89, SOC=-25.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.40
#
# Step 260:
#   Before Action: Demand=862.74, Price=31.83, SOC=-25.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.50
#
# Step 261:
#   Before Action: Demand=884.88, Price=30.28, SOC=-25.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.60
#
# Step 262:
#   Before Action: Demand=868.14, Price=31.06, SOC=-25.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.70
#
# Step 263:
#   Before Action: Demand=817.92, Price=26.01, SOC=-25.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.80
#
# Step 264:
#   Before Action: Demand=741.06, Price=24.30, SOC=-25.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-25.90
#
# Step 265:
#   Before Action: Demand=629.82, Price=22.92, SOC=-25.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.00
#
# Step 266:
#   Before Action: Demand=539.10, Price=20.95, SOC=-26.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.10
#
# Step 267:
#   Before Action: Demand=492.84, Price=19.00, SOC=-26.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.20
#
# Step 268:
#   Before Action: Demand=531.18, Price=18.58, SOC=-26.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.30
#
# Step 269:
#   Before Action: Demand=524.16, Price=19.17, SOC=-26.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.40
#
# Step 270:
#   Before Action: Demand=510.12, Price=20.95, SOC=-26.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.50
#
# Step 271:
#   Before Action: Demand=628.38, Price=22.49, SOC=-26.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.60
#
# Step 272:
#   Before Action: Demand=741.78, Price=22.41, SOC=-26.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.70
#
# Step 273:
#   Before Action: Demand=785.34, Price=23.29, SOC=-26.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.80
#
# Step 274:
#   Before Action: Demand=709.02, Price=24.91, SOC=-26.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-26.90
#
# Step 275:
#   Before Action: Demand=646.20, Price=26.86, SOC=-26.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.00
#
# Step 276:
#   Before Action: Demand=626.94, Price=27.80, SOC=-27.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.10
#
# Step 277:
#   Before Action: Demand=628.38, Price=28.64, SOC=-27.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.20
#
# Step 278:
#   Before Action: Demand=670.32, Price=29.84, SOC=-27.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.30
#
# Step 279:
#   Before Action: Demand=612.54, Price=33.24, SOC=-27.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.40
#
# Step 280:
#   Before Action: Demand=619.74, Price=33.77, SOC=-27.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.50
#
# Step 281:
#   Before Action: Demand=627.12, Price=38.73, SOC=-27.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.60
#
# Step 282:
#   Before Action: Demand=668.16, Price=44.10, SOC=-27.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.70
#
# Step 283:
#   Before Action: Demand=770.04, Price=39.86, SOC=-27.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.80
#
# Step 284:
#   Before Action: Demand=802.80, Price=40.39, SOC=-27.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-27.90
#
# Step 285:
#   Before Action: Demand=865.08, Price=39.70, SOC=-27.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.00
#
# Step 286:
#   Before Action: Demand=865.62, Price=41.52, SOC=-28.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.10
#
# Step 287:
#   Before Action: Demand=820.80, Price=28.96, SOC=-28.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.20
#
# Step 288:
#   Before Action: Demand=752.76, Price=25.62, SOC=-28.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.30
#
# Step 289:
#   Before Action: Demand=659.88, Price=22.69, SOC=-28.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.40
#
# Step 290:
#   Before Action: Demand=577.44, Price=22.72, SOC=-28.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.50
#
# Step 291:
#   Before Action: Demand=522.00, Price=21.53, SOC=-28.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.60
#
# Step 292:
#   Before Action: Demand=551.52, Price=20.18, SOC=-28.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.70
#
# Step 293:
#   Before Action: Demand=528.48, Price=20.24, SOC=-28.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.80
#
# Step 294:
#   Before Action: Demand=495.72, Price=21.78, SOC=-28.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-28.90
#
# Step 295:
#   Before Action: Demand=548.64, Price=23.34, SOC=-28.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.00
#
# Step 296:
#   Before Action: Demand=642.42, Price=25.82, SOC=-29.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.10
#
# Step 297:
#   Before Action: Demand=764.10, Price=26.92, SOC=-29.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.20
#
# Step 298:
#   Before Action: Demand=768.60, Price=29.67, SOC=-29.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.30
#
# Step 299:
#   Before Action: Demand=744.66, Price=32.00, SOC=-29.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.40
#
# Step 300:
#   Before Action: Demand=746.46, Price=50.56, SOC=-29.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.50
#
# Step 301:
#   Before Action: Demand=740.34, Price=38.60, SOC=-29.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.60
#
# Step 302:
#   Before Action: Demand=780.84, Price=43.39, SOC=-29.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.70
#
# Step 303:
#   Before Action: Demand=708.48, Price=54.19, SOC=-29.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.80
#
# Step 304:
#   Before Action: Demand=709.02, Price=38.21, SOC=-29.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-29.90
#
# Step 305:
#   Before Action: Demand=706.14, Price=42.68, SOC=-29.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.00
#
# Step 306:
#   Before Action: Demand=748.08, Price=37.69, SOC=-30.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.10
#
# Step 307:
#   Before Action: Demand=876.06, Price=39.88, SOC=-30.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.20
#
# Step 308:
#   Before Action: Demand=878.40, Price=41.62, SOC=-30.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.30
#
# Step 309:
#   Before Action: Demand=923.40, Price=37.04, SOC=-30.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.40
#
# Step 310:
#   Before Action: Demand=910.44, Price=32.45, SOC=-30.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.50
#
# Step 311:
#   Before Action: Demand=865.62, Price=27.29, SOC=-30.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.60
#
# Step 312:
#   Before Action: Demand=768.42, Price=24.38, SOC=-30.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.70
#
# Step 313:
#   Before Action: Demand=658.80, Price=22.84, SOC=-30.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.80
#
# Step 314:
#   Before Action: Demand=554.76, Price=22.10, SOC=-30.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-30.90
#
# Step 315:
#   Before Action: Demand=507.42, Price=21.33, SOC=-30.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.00
#
# Step 316:
#   Before Action: Demand=480.60, Price=19.77, SOC=-31.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.10
#
# Step 317:
#   Before Action: Demand=575.64, Price=20.61, SOC=-31.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.20
#
# Step 318:
#   Before Action: Demand=518.58, Price=22.05, SOC=-31.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.30
#
# Step 319:
#   Before Action: Demand=643.14, Price=22.86, SOC=-31.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.40
#
# Step 320:
#   Before Action: Demand=763.56, Price=24.77, SOC=-31.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.50
#
# Step 321:
#   Before Action: Demand=806.76, Price=26.31, SOC=-31.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.60
#
# Step 322:
#   Before Action: Demand=714.96, Price=28.19, SOC=-31.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.70
#
# Step 323:
#   Before Action: Demand=645.48, Price=33.59, SOC=-31.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.80
#
# Step 324:
#   Before Action: Demand=631.26, Price=33.89, SOC=-31.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-31.90
#
# Step 325:
#   Before Action: Demand=631.98, Price=49.13, SOC=-31.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.00
#
# Step 326:
#   Before Action: Demand=666.54, Price=38.89, SOC=-32.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.10
#
# Step 327:
#   Before Action: Demand=613.26, Price=37.64, SOC=-32.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.20
#
# Step 328:
#   Before Action: Demand=567.18, Price=58.98, SOC=-32.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.30
#
# Step 329:
#   Before Action: Demand=123.12, Price=30.53, SOC=-32.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.40
#
# Step 330:
#   Before Action: Demand=621.00, Price=30.60, SOC=-32.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.50
#
# Step 331:
#   Before Action: Demand=813.06, Price=33.62, SOC=-32.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.60
#
# Step 332:
#   Before Action: Demand=853.20, Price=27.16, SOC=-32.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.70
#
# Step 333:
#   Before Action: Demand=886.50, Price=26.91, SOC=-32.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.80
#
# Step 334:
#   Before Action: Demand=883.08, Price=27.12, SOC=-32.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-32.90
#
# Step 335:
#   Before Action: Demand=839.16, Price=24.12, SOC=-32.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.00
#
# Step 336:
#   Before Action: Demand=766.08, Price=20.23, SOC=-33.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.10
#
# Step 337:
#   Before Action: Demand=666.00, Price=21.21, SOC=-33.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.20
#
# Step 338:
#   Before Action: Demand=558.90, Price=21.29, SOC=-33.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.30
#
# Step 339:
#   Before Action: Demand=504.72, Price=18.77, SOC=-33.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.40
#
# Step 340:
#   Before Action: Demand=509.22, Price=18.32, SOC=-33.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.50
#
# Step 341:
#   Before Action: Demand=549.18, Price=17.85, SOC=-33.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.60
#
# Step 342:
#   Before Action: Demand=504.18, Price=17.99, SOC=-33.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.70
#
# Step 343:
#   Before Action: Demand=607.50, Price=16.79, SOC=-33.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.80
#
# Step 344:
#   Before Action: Demand=738.54, Price=17.90, SOC=-33.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-33.90
#
# Step 345:
#   Before Action: Demand=758.70, Price=20.82, SOC=-33.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.00
#
# Step 346:
#   Before Action: Demand=696.24, Price=22.18, SOC=-34.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.10
#
# Step 347:
#   Before Action: Demand=640.80, Price=24.86, SOC=-34.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.20
#
# Step 348:
#   Before Action: Demand=623.52, Price=27.97, SOC=-34.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.30
#
# Step 349:
#   Before Action: Demand=617.04, Price=29.28, SOC=-34.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.40
#
# Step 350:
#   Before Action: Demand=663.30, Price=30.27, SOC=-34.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.50
#
# Step 351:
#   Before Action: Demand=593.46, Price=29.20, SOC=-34.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.60
#
# Step 352:
#   Before Action: Demand=603.72, Price=31.43, SOC=-34.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.70
#
# Step 353:
#   Before Action: Demand=624.42, Price=30.89, SOC=-34.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.80
#
# Step 354:
#   Before Action: Demand=674.10, Price=61.45, SOC=-34.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-34.90
#
# Step 355:
#   Before Action: Demand=780.66, Price=31.11, SOC=-34.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.00
#
# Step 356:
#   Before Action: Demand=802.08, Price=29.93, SOC=-35.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.10
#
# Step 357:
#   Before Action: Demand=845.64, Price=26.17, SOC=-35.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.20
#
# Step 358:
#   Before Action: Demand=857.52, Price=26.81, SOC=-35.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.30
#
# Step 359:
#   Before Action: Demand=825.30, Price=23.43, SOC=-35.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.40
#
# Step 360:
#   Before Action: Demand=762.84, Price=20.01, SOC=-35.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.50
#
# Step 361:
#   Before Action: Demand=683.82, Price=19.49, SOC=-35.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.60
#
# Step 362:
#   Before Action: Demand=588.06, Price=20.77, SOC=-35.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.70
#
# Step 363:
#   Before Action: Demand=527.04, Price=16.90, SOC=-35.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.80
#
# Step 364:
#   Before Action: Demand=544.14, Price=17.07, SOC=-35.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-35.90
#
# Step 365:
#   Before Action: Demand=550.98, Price=16.81, SOC=-35.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-36.00
#
# Step 366:
#   Before Action: Demand=505.08, Price=11.38, SOC=-36.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-36.10
#
# Step 367:
# ...
#
# Step 880:
#   Before Action: Demand=709.92, Price=22.15, SOC=-87.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-87.50
#
# Step 881:
#   Before Action: Demand=702.18, Price=22.61, SOC=-87.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-87.60
#
# Step 882:
#   Before Action: Demand=738.00, Price=23.18, SOC=-87.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-87.70
#
# Step 883:
#   Before Action: Demand=858.96, Price=22.64, SOC=-87.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-87.80
#
# Step 884:
#   Before Action: Demand=876.96, Price=23.96, SOC=-87.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-87.90
#
# Step 885:
#   Before Action: Demand=891.18, Price=26.47, SOC=-87.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.00
#
# Step 886:
#   Before Action: Demand=874.44, Price=21.83, SOC=-88.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.10
#
# Step 887:
#   Before Action: Demand=844.92, Price=18.81, SOC=-88.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.20
#
# Step 888:
#   Before Action: Demand=778.14, Price=18.48, SOC=-88.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.30
#
# Step 889:
#   Before Action: Demand=686.34, Price=16.10, SOC=-88.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.40
#
# Step 890:
#   Before Action: Demand=589.14, Price=17.53, SOC=-88.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.50
#
# Step 891:
#   Before Action: Demand=534.78, Price=17.57, SOC=-88.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.60
#
# Step 892:
#   Before Action: Demand=562.14, Price=16.45, SOC=-88.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.70
#
# Step 893:
#   Before Action: Demand=512.10, Price=17.06, SOC=-88.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.80
#
# Step 894:
#   Before Action: Demand=496.80, Price=19.27, SOC=-88.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-88.90
#
# Step 895:
#   Before Action: Demand=535.68, Price=20.05, SOC=-88.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.00
#
# Step 896:
#   Before Action: Demand=619.56, Price=21.71, SOC=-89.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.10
#
# Step 897:
#   Before Action: Demand=703.44, Price=22.14, SOC=-89.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.20
#
# Step 898:
#   Before Action: Demand=742.86, Price=23.43, SOC=-89.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.30
#
# Step 899:
#   Before Action: Demand=801.00, Price=24.72, SOC=-89.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.40
#
# Step 900:
#   Before Action: Demand=746.64, Price=23.69, SOC=-89.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.50
#
# Step 901:
#   Before Action: Demand=746.64, Price=25.39, SOC=-89.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.60
#
# Step 902:
#   Before Action: Demand=732.60, Price=24.47, SOC=-89.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.70
#
# Step 903:
#   Before Action: Demand=722.52, Price=23.96, SOC=-89.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.80
#
# Step 904:
#   Before Action: Demand=718.74, Price=24.74, SOC=-89.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-89.90
#
# Step 905:
#   Before Action: Demand=728.46, Price=25.39, SOC=-89.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.00
#
# Step 906:
#   Before Action: Demand=776.34, Price=24.99, SOC=-90.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.10
#
# Step 907:
#   Before Action: Demand=922.32, Price=25.80, SOC=-90.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.20
#
# Step 908:
#   Before Action: Demand=947.70, Price=24.22, SOC=-90.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.30
#
# Step 909:
#   Before Action: Demand=958.14, Price=23.65, SOC=-90.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.40
#
# Step 910:
#   Before Action: Demand=935.64, Price=22.03, SOC=-90.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.50
#
# Step 911:
#   Before Action: Demand=885.06, Price=19.35, SOC=-90.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.60
#
# Step 912:
#   Before Action: Demand=769.86, Price=17.98, SOC=-90.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.70
#
# Step 913:
#   Before Action: Demand=655.20, Price=17.03, SOC=-90.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.80
#
# Step 914:
#   Before Action: Demand=559.80, Price=17.77, SOC=-90.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-90.90
#
# Step 915:
#   Before Action: Demand=511.20, Price=16.39, SOC=-90.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.00
#
# Step 916:
#   Before Action: Demand=531.90, Price=15.60, SOC=-91.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.10
#
# Step 917:
#   Before Action: Demand=524.16, Price=15.61, SOC=-91.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.20
#
# Step 918:
#   Before Action: Demand=513.36, Price=17.78, SOC=-91.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.30
#
# Step 919:
#   Before Action: Demand=633.24, Price=18.07, SOC=-91.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.40
#
# Step 920:
#   Before Action: Demand=752.04, Price=17.16, SOC=-91.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.50
#
# Step 921:
#   Before Action: Demand=736.74, Price=20.51, SOC=-91.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.60
#
# Step 922:
#   Before Action: Demand=694.44, Price=22.08, SOC=-91.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.70
#
# Step 923:
#   Before Action: Demand=724.32, Price=22.75, SOC=-91.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.80
#
# Step 924:
#   Before Action: Demand=672.84, Price=23.89, SOC=-91.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-91.90
#
# Step 925:
#   Before Action: Demand=666.54, Price=24.56, SOC=-91.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.00
#
# Step 926:
#   Before Action: Demand=640.44, Price=24.78, SOC=-92.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.10
#
# Step 927:
#   Before Action: Demand=650.52, Price=27.11, SOC=-92.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.20
#
# Step 928:
#   Before Action: Demand=665.46, Price=27.55, SOC=-92.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.30
#
# Step 929:
#   Before Action: Demand=671.94, Price=37.17, SOC=-92.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.40
#
# Step 930:
#   Before Action: Demand=722.52, Price=39.33, SOC=-92.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.50
#
# Step 931:
#   Before Action: Demand=858.06, Price=40.60, SOC=-92.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.60
#
# Step 932:
#   Before Action: Demand=926.82, Price=25.89, SOC=-92.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.70
#
# Step 933:
#   Before Action: Demand=914.04, Price=31.51, SOC=-92.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.80
#
# Step 934:
#   Before Action: Demand=893.70, Price=25.16, SOC=-92.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-92.90
#
# Step 935:
#   Before Action: Demand=833.76, Price=20.62, SOC=-92.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.00
#
# Step 936:
#   Before Action: Demand=747.00, Price=19.10, SOC=-93.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.10
#
# Step 937:
#   Before Action: Demand=635.04, Price=19.39, SOC=-93.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.20
#
# Step 938:
#   Before Action: Demand=550.08, Price=18.77, SOC=-93.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.30
#
# Step 939:
#   Before Action: Demand=506.70, Price=18.03, SOC=-93.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.40
#
# Step 940:
#   Before Action: Demand=548.28, Price=16.88, SOC=-93.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.50
#
# Step 941:
#   Before Action: Demand=514.62, Price=17.18, SOC=-93.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.60
#
# Step 942:
#   Before Action: Demand=504.54, Price=18.76, SOC=-93.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.70
#
# Step 943:
#   Before Action: Demand=624.42, Price=19.14, SOC=-93.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.80
#
# Step 944:
#   Before Action: Demand=740.70, Price=20.16, SOC=-93.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-93.90
#
# Step 945:
#   Before Action: Demand=734.40, Price=21.03, SOC=-93.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.00
#
# Step 946:
#   Before Action: Demand=694.08, Price=22.72, SOC=-94.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.10
#
# Step 947:
#   Before Action: Demand=714.96, Price=27.10, SOC=-94.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.20
#
# Step 948:
#   Before Action: Demand=658.62, Price=28.26, SOC=-94.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.30
#
# Step 949:
#   Before Action: Demand=644.58, Price=28.58, SOC=-94.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.40
#
# Step 950:
#   Before Action: Demand=635.22, Price=30.21, SOC=-94.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.50
#
# Step 951:
#   Before Action: Demand=628.74, Price=42.54, SOC=-94.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.60
#
# Step 952:
#   Before Action: Demand=662.04, Price=44.32, SOC=-94.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.70
#
# Step 953:
#   Before Action: Demand=685.44, Price=50.32, SOC=-94.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.80
#
# Step 954:
#   Before Action: Demand=751.32, Price=43.99, SOC=-94.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-94.90
#
# Step 955:
#   Before Action: Demand=929.34, Price=34.06, SOC=-94.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.00
#
# Step 956:
#   Before Action: Demand=975.06, Price=31.40, SOC=-95.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.10
#
# Step 957:
#   Before Action: Demand=999.54, Price=32.98, SOC=-95.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.20
#
# Step 958:
#   Before Action: Demand=984.60, Price=26.65, SOC=-95.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.30
#
# Step 959:
#   Before Action: Demand=914.40, Price=22.40, SOC=-95.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.40
#
# Step 960:
#   Before Action: Demand=816.12, Price=20.56, SOC=-95.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.50
#
# Step 961:
#   Before Action: Demand=691.38, Price=18.51, SOC=-95.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.60
#
# Step 962:
#   Before Action: Demand=597.78, Price=18.16, SOC=-95.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.70
#
# Step 963:
#   Before Action: Demand=545.76, Price=16.03, SOC=-95.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.80
#
# Step 964:
#   Before Action: Demand=577.62, Price=14.24, SOC=-95.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-95.90
#
# Step 965:
#   Before Action: Demand=554.76, Price=13.90, SOC=-95.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.00
#
# Step 966:
#   Before Action: Demand=533.16, Price=17.61, SOC=-96.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.10
#
# Step 967:
#   Before Action: Demand=658.08, Price=19.27, SOC=-96.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.20
#
# Step 968:
#   Before Action: Demand=801.18, Price=18.80, SOC=-96.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.30
#
# Step 969:
#   Before Action: Demand=798.30, Price=21.29, SOC=-96.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.40
#
# Step 970:
#   Before Action: Demand=747.54, Price=24.37, SOC=-96.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.50
#
# Step 971:
#   Before Action: Demand=777.24, Price=27.88, SOC=-96.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.60
#
# Step 972:
#   Before Action: Demand=711.54, Price=27.77, SOC=-96.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.70
#
# Step 973:
#   Before Action: Demand=720.18, Price=26.36, SOC=-96.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.80
#
# Step 974:
#   Before Action: Demand=720.18, Price=28.97, SOC=-96.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-96.90
#
# Step 975:
#   Before Action: Demand=713.88, Price=40.80, SOC=-96.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.00
#
# Step 976:
#   Before Action: Demand=715.14, Price=32.52, SOC=-97.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.10
#
# Step 977:
#   Before Action: Demand=748.26, Price=35.66, SOC=-97.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.20
#
# Step 978:
#   Before Action: Demand=790.92, Price=34.44, SOC=-97.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.30
#
# Step 979:
#   Before Action: Demand=959.04, Price=33.45, SOC=-97.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.40
#
# Step 980:
#   Before Action: Demand=989.46, Price=27.20, SOC=-97.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.50
#
# Step 981:
#   Before Action: Demand=1060.56, Price=28.98, SOC=-97.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.60
#
# Step 982:
#   Before Action: Demand=1063.26, Price=26.45, SOC=-97.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.70
#
# Step 983:
#   Before Action: Demand=990.54, Price=21.95, SOC=-97.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.80
#
# Step 984:
#   Before Action: Demand=863.46, Price=22.18, SOC=-97.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-97.90
#
# Step 985:
#   Before Action: Demand=736.74, Price=19.84, SOC=-97.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.00
#
# Step 986:
#   Before Action: Demand=630.00, Price=19.68, SOC=-98.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.10
#
# Step 987:
#   Before Action: Demand=573.12, Price=17.94, SOC=-98.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.20
#
# Step 988:
#   Before Action: Demand=569.16, Price=17.50, SOC=-98.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.30
#
# Step 989:
#   Before Action: Demand=619.38, Price=18.26, SOC=-98.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.40
#
# Step 990:
#   Before Action: Demand=569.34, Price=20.52, SOC=-98.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.50
#
# Step 991:
#   Before Action: Demand=699.12, Price=21.20, SOC=-98.50  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.60
#
# Step 992:
#   Before Action: Demand=817.38, Price=21.37, SOC=-98.60  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.70
#
# Step 993:
#   Before Action: Demand=811.44, Price=22.98, SOC=-98.70  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.80
#
# Step 994:
#   Before Action: Demand=761.04, Price=25.84, SOC=-98.80  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-98.90
#
# Step 995:
#   Before Action: Demand=765.72, Price=29.41, SOC=-98.90  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.00
#
# Step 996:
#   Before Action: Demand=719.10, Price=26.29, SOC=-99.00  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.10
#
# Step 997:
#   Before Action: Demand=738.00, Price=35.00, SOC=-99.10  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.20
#
# Step 998:
#   Before Action: Demand=760.32, Price=33.96, SOC=-99.20  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.30
#
# Step 999:
#   Before Action: Demand=727.38, Price=28.57, SOC=-99.30  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.40
#
# Step 1000:
#   Before Action: Demand=740.34, Price=28.98, SOC=-99.40  |  After Action: Action=-0.10, Reward=-1.00e+04, New SOC=-99.50

# %% [markdown]
# ##### A2C

# %%
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = A2C("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("a2c_energy_management")
print("Training Done")

# %%
import gym
from stable_baselines3 import A2C
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

env = gym.make(env_id)
model = A2C.load("a2c_energy_management")

observation = env.reset()
for t in range(1000):
    print(f"Step {t + 1}:")
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")
    action, _states = model.predict(observation)
    observation, reward, done, _ = env.step(action)
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()

# %% [markdown]
# ##### A3C

# %%
import gym
from stable_baselines3 import A3C
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = A3C("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("a3c_energy_management")
print("Training Done")
# Out:
# C:\Users\mf36244\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# C:\Users\mf36244\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 5177 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
import gym
from stable_baselines3 import A3C
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

env = gym.make(env_id)
model = A3C.load("a3c_energy_management")

observation = env.reset()
for t in range(1000):
    print(f"Step {t + 1}:")
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")
    action, _states = model.predict(observation)
    observation, reward, done, _ = env.step(action)
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\mf36244\Downloads\Learning-based Optimal Control\Envrionment.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mf36244/Downloads/Learning-based%20Optimal%20Control/Envrionment.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> from stable_baselines3 import PPO
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mf36244/Downloads/Learning-based%20Optimal%20Control/Envrionment.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> from stable_baselines3.common.envs import DummyVecEnv
#       <a href='vscode-notebook-cell:/c%3A/Users/mf36244/Downloads/Learning-based%20Optimal%20Control/Envrionment.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> # Assuming env_id is the ID of your custom environment ('EnergyManagement-v0' in your case)
#       <a href='vscode-notebook-cell:/c%3A/Users/mf36244/Downloads/Learning-based%20Optimal%20Control/Envrionment.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> env_id = 'EnergyManagement-v0'
#
# ImportError: cannot import name 'DummyVecEnv' from 'stable_baselines3.common.envs' (C:\Users\mf36244\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\envs\__init__.py)

# %% [markdown]
# ##### TD3

# %%
import gym
from stable_baselines3 import TD3
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = TD3("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("td3_energy_management")
print("Training Done")

# %%
import gym
from stable_baselines3 import TD3
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

env = gym.make(env_id)
model = TD3.load("td3_energy_management")

observation = env.reset()
for t in range(1000):
    print(f"Step {t + 1}:")
    print(f"  Before Action: Demand={observation[0]:.2f}, Price={observation[2]:.2f}, SOC={observation[1]:.2f}", end="")
    action, _states = model.predict(observation)
    observation, reward, done, _ = env.step(action)
    print(f"  |  After Action: Action={action:.2f}, Reward={reward:.2e}, New SOC={observation[1]:.2f}")
    print()

env.close()

# %%
import gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = DQN("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("dqn_energy_management")
print("Training Done")

# %% [markdown]
# ##### DQN

# %%
import gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from energy_management_env import EnergyManagementEnv

env_id = 'EnergyManagement-v0'

def make_env():
    return gym.make(env_id)

num_envs = 8
vec_env = DummyVecEnv([make_env for _ in range(num_envs)])
vec_env = VecNormalize(vec_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

model = DQN("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1e6)
model.save("dqn_energy_management")
print("Training Done")
